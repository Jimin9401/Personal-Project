# %%
import pandas as pd
import requests
from selenium import webdriver
from bs4 import BeautifulSoup
from urllib import parse
import urllib3 as ulb
import json
import urllib.parse
import re
import time

# %%
webscrape=webdriver.Chrome('./chromedriver.exe')
#chromedriver로 페이지 열기

# %%
url='https://www.twitch.tv/videos/'
code='278501686'

# %%
url+code
# Out:
# 'https://www.twitch.tv/videos/325411081'

# %%
webscrape.get('https://www.youtube.com/watch?v=c_IVcbEez8o')
# 쇼핑몰 리뷰사이트로 가기

# %%
example=[]

# %%
while True:
    html=webscrape.page_source
    #현재 페이지 소스 html에 저장

    soup=BeautifulSoup(html,'html.parser')
    #beautifulSoup 함수를 통해 위에 페이지 소스 html parsing 하기

    star=soup.select('#secondary-inner') 
    # css selector를 통해 별점 정보만 긁어오기

    li=[]
    for i in star:
        li.append(i.text.strip())
    a=li[0].split('에게 회신링크 복사')
    
    for n in a:
        example.append(n)
        
    example=list(set(example))
    
    print('--------------------------------------')
    print(len(example))
    
#    for i in a:
 #       print(re.split('동영상 채팅|동영상으로 이동|에게 회신링크 복사|게시됨 3개월 전|',i))
        
  #  for i in a:
   #     total_review.append(re.split('동영상 채팅|동영상으로 이동|에게 회신링크 복사|게시됨 3개월 전|',i))
#
time.sleep(0.5)
# Out:
# --------------------------------------
# 4
# --------------------------------------
# 4
# --------------------------------------
# 4
# --------------------------------------
# 4
# --------------------------------------
# 4
# --------------------------------------
# 4
# --------------------------------------
# 4
# --------------------------------------
# 4
# --------------------------------------
# 4
# --------------------------------------
# 4
# --------------------------------------
# 4
# --------------------------------------
# 4
# --------------------------------------
# 4
# --------------------------------------
# 4
# --------------------------------------
# 4
# --------------------------------------
# 4
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-a5d408a34759> in <module>
#       1 while True:
# ----> 2     html=webscrape.page_source
#       3     #현재 페이지 소스 html에 저장
#       4
#       5     soup=BeautifulSoup(html,'html.parser')
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in page_source(self)
#     677             driver.page_source
#     678         """
# --> 679         return self.execute(Command.GET_PAGE_SOURCE)['value']
#     680
#     681     def close(self):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py in execute(self, command, params)
#     374         data = utils.dump_json(params)
#     375         url = '%s%s' % (self._url, path)
# --> 376         return self._request(command_info[0], url, body=data)
#     377
#     378     def _request(self, method, url, body=None):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py in _request(self, method, url, body)
#     397
#     398         if self.keep_alive:
# --> 399             resp = self._conn.request(method, url, body=body, headers=headers)
#     400
#     401             statuscode = resp.status
#
# ~\Anaconda3\lib\site-packages\urllib3\request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      66             return self.request_encode_url(method, url, fields=fields,
#      67                                            headers=headers,
# ---> 68                                            **urlopen_kw)
#      69         else:
#      70             return self.request_encode_body(method, url, fields=fields,
#
# ~\Anaconda3\lib\site-packages\urllib3\request.py in request_encode_url(self, method, url, fields, headers, **urlopen_kw)
#      87             url += '?' + urlencode(fields)
#      88
# ---> 89         return self.urlopen(method, url, **extra_kw)
#      90
#      91     def request_encode_body(self, method, url, fields=None, headers=None,
#
# ~\Anaconda3\lib\site-packages\urllib3\poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     320             response = conn.urlopen(method, url, **kw)
#     321         else:
# --> 322             response = conn.urlopen(method, u.request_uri, **kw)
#     323
#     324         redirect_location = redirect and response.get_redirect_location()
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 2.6 and older, Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# ~\Anaconda3\lib\http\client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# ~\Anaconda3\lib\http\client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# ~\Anaconda3\lib\http\client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
example
# Out:
# ['',
#  "채팅 숨기기\n\n\n\n\n\n\n\n\n\n\n\n\n\n다음 동영상\n자동재생\n\n\n\n\n\n\n      자동재생을 사용하도록 설정하면 추천 동영상이 자동으로 이어서 재생됩니다.\n    \n\n\n\n\n\n\n\n\n      40:48\n    \n\n\n\n\n\n\n\n\n\n            Smoke & Study 2 | Chill Mix\n          \n\n\n\n\n\nthe bootleg boy\n\n\n\n\n\n\n\n\n\n      인증됨\n    \n\n\n\n\n•\n\n\n조회수 141만회\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n50+\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n          관련 재생목록 - lofi hip hop radio - beats to sleep/relax to 😴\n        \n\n\n\n\n\nYouTube\n\n\n\n•\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n            lofi hip hop radio 24/7 - chill study/relax/gaming beats 🐾\n          \n\n\n\n\n\nChillhop Music\n\n\n\n\n\n\n\n\n\n      인증됨\n    \n\n\n\n\n•\n\n\n2.5천명 시청 중\n\n\n\n\n\n\n\n\n\n\n실시간 스트리밍 중\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n            24/7 lofi hip hop radio - beats to study/chill/relax\n          \n\n\n\n\n\nCollege Music\n\n\n\n\n\n\n\n\n\n      인증됨\n    \n\n\n\n\n•\n\n\n495명 시청 중\n\n\n\n\n\n\n\n\n\n\n실시간 스트리밍 중\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n      17:27\n    \n\n\n\n\n\n\n\n\n\n            ＮＯ ＳＬＥＥＰ 4\n          \n\n\n\n\n\nthe bootleg boy\n\n\n\n\n\n\n\n\n\n      인증됨\n    \n\n\n\n\n•\n\n\n조회수 70만회\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n            日文、動漫音樂電台 | Anime Music➨24/7\n          \n\n\n\n\n\n親親2o音樂LîvË【日系音樂】\n\n\n\n•\n\n\n667명 시청 중\n\n\n\n\n\n\n\n\n\n\n실시간 스트리밍 중\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n      28:42\n    \n\n\n\n\n\n\n\n\n\n            Nymano - Short Stories [Full BeatTape]\n          \n\n\n\n\n\nSTEEZYASFUCK\n\n\n\n\n\n\n\n\n\n      인증됨\n    \n\n\n\n\n•\n\n\n조회수 154만회\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n            Tropical House Radio | 24/7 Livestream\n          \n\n\n\n\n\nFuture House Radio\n\n\n\n\n\n\n\n\n\n      인증됨\n    \n\n\n\n\n•\n\n\n178명 시청 중\n\n\n\n\n\n\n\n\n\n\n실시간 스트리밍 중\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n      1:52:03\n    \n\n\n\n\n\n\n\n\n\n            That 2 A.M. Fresh Air\n          \n\n\n\n\n\nHomework Radio\n\n\n\n•\n\n\n조회수 63만회\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n      8:09:25\n    \n\n\n\n\n\n\n\n\n\n            8 Hours of Powerful Theta Waves Healing for Deep Meditation, Improve Memory, Massage, Sleep, Massage\n          \n\n\n\n\n\nMeditation Relax Music\n\n\n\n\n\n\n\n\n\n      인증됨\n    \n\n\n\n\n•\n\n\n조회수 229만회\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n      26:45\n    \n\n\n\n\n\n\n\n\n\n            Sleepless nights - lofi hiphop mix pt.4\n          \n\n\n\n\n\nChilledCow\n\n\n\n\n\n\n\n\n\n      인증됨\n    \n\n\n\n\n•\n\n\n조회수 362만회\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n      18:38\n    \n\n\n\n\n\n\n\n\n\n            RAINING IN ＰＡＲＩＳ (Lofi HipHop)\n          \n\n\n\n\n\nthe bootleg boy\n\n\n\n\n\n\n\n\n\n      인증됨\n    \n\n\n\n\n•\n\n\n조회수 151만회\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n      40:14\n    \n\n\n\n\n\n\n\n\n\n            Smoke & Study | Chill Mix\n          \n\n\n\n\n\nthe bootleg boy\n\n\n\n\n\n\n\n\n\n      인증됨\n    \n\n\n\n\n•\n\n\n조회수 387만회\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n      2:00:01\n    \n\n\n\n\n\n\n\n\n\n            Lofi hip hop mix - Beats to Relax/Study to [2018]\n          \n\n\n\n\n\nChilledCow\n\n\n\n\n\n\n\n\n\n      인증됨\n    \n\n\n\n\n•\n\n\n조회수 1166만회\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n      1:53:32\n    \n\n\n\n\n\n\n\n\n\n            It's 5 A.M. and I haven't slept\n          \n\n\n\n\n\nHomework Radio\n\n\n\n•\n\n\n조회수 6.3만회\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n      1:00:37\n    \n\n\n\n\n\n\n\n\n\n            ｈｏｍｅｗｏｒｋ ＆ ｓｔｕｄｙ ｍｕｓｉｃ （ミュージック）\n          \n\n\n\n\n\nR L I F E\n\n\n\n\n\n\n\n\n\n      인증됨\n    \n\n\n\n\n•\n\n\n조회수 248만회\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n      1:01:02\n    \n\n\n\n\n\n\n\n\n\n            Space walks ~ lofi hip hop mix | beats to relax/study to\n          \n\n\n\n\n\nDreamy\n\n\n\n•\n\n\n조회수 93만회\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n      5:34:21\n    \n\n\n\n\n\n\n\n\n\n            24/7 - Chilled Tide Beats 🎧 Lofi Hip Hop - Study Music\n          \n\n\n\n\n\nChilledTideBeats\n\n\n\n•\n\n\n조회수 85만회\n\n\n\n\n\n\n\n\ ...
#  '채팅 숨기기',
#  'if (window.ytcsi) {window.ytcsi.tick("bs", null, \'\');}ytcfg.set(\'initialBodyClientWidth\', document.body.clientWidth);window.ytcfg.set(\'SERVICE_WORKER_KILLSWITCH\', false); if (window.ytcsi) {window.ytcsi.tick("bc", null, \'\');}\n\n\n\n\n\n\n\nif (window.ytcsi) {window.ytcsi.tick("cfg", null, \'\');} var ytplayer = ytplayer || {};ytplayer.config = {"params":{"allowfullscreen":"true","allowscriptaccess":"always","bgcolor":"#000000"},"sts":17850,"args":{"ad_preroll":"1","innertube_api_key":"AIzaSyAO_FJ2SlqU8Q4STEHLGCilw_Y9_11qcW8","live_chunk_readahead":"3","transparent_background":"1","player_error_log_fraction":"1.0","latency_class":"NORMAL","ad3_module":"1","ssl":"1","host_language":"ko","ptk":"youtube_single","rmktEnabled":"1","vm":"CAEQARgE","pltype":"contentlive","fade_out_duration_milliseconds":"1000","midroll_prefetch_size":"1","oid":"u0H2Pd34OsV-e42D6dwHaA","midroll_freqcap":"420.0","ad_tag":"https:\\/\\/pubads.g.doubleclick.net\\/gampad\\/ads?ad_rule=0\\u0026ciu_szs=300x60\\u0026correlator=4037716131419183406\\u0026env=vp\\u0026gdfp_req=1\\u0026ip=175.195.197.176\\u0026iu=\\/4061\\/com.ytpwmpu.music\\u0026loeid=23757209,23775644,23773251,23769156,23761460\\u0026osd=2\\u0026output=xml_vast3\\u0026pucrd=CgYIABAAGAB4Ag\\u0026scor=1\\u0026scp=adtest%3Dnodebugip%26av%3D1%26kpeid%3DsIg9WMfxjZZvwROleiVsQg%26kpid%3D13262895%26kpu%3D562Steezy%26kvid%3Dc_IVcbEez8o%26live%3D1%26mpvid%3DdJmdcebwVEoFFwha%26ssl%3D1%26afv%3D1%26dbp%3DChZtNGpZWVh3TURMZ3BlZEYwMHktcjRnEAEgASgAOAE%26dc_lsv%3D1%26dc_sr%3D1%26dc_yt%3D1%26excl_cat%3D13262895,live%26busb%3D1%26k2%3D3,35,215,588,592,1030%26k5%3D3_35_215_588_592_1030%26kcountry%3Dkr%26kga%3D-1%26kgg%3D-1%26kgpt%3D1%26klg%3Dko%26kmyd%3Dwatch-longform-ad%26ko%3Dp%26ktype%3Dgptc%26kvlg%3Den%26kvz%3D205%26lu%3D001a1,1017a1,6681%26nga%3D1%26nlfb%3D1%26pos%3Dpre%26yt1st%3D1%26yt3pav%3D1%26ytcat%3D10%26ytdevice%3D1%26ytdevicever%3D2.20181115%26ytexp%3D9489025,23777186,23774947,23757412,23774306,23758598,23773607,23778824,23774433,9471239,9469036,23735277,23779311,23771857,9474356,23769086,23769433,23766073,23767226,9450140,23733598,9477942%26yt_ec%3D6%26yt_ec2%3D16%26yt_vrallowed%3D1\\u0026sdkv=h.3.0.0\\u0026sdki=18803DFD\\u0026sdr=1\\u0026sz=480x360%7C480x361\\u0026unviewed_position_start=1\\u0026url=https%3A\\/\\/www.youtube.com\\/video\\/c_IVcbEez8o\\u0026vid=c_IVcbEez8o\\u0026vpos=preroll\\u0026ytdevice=1\\u0026yt_pt=APb3F2-vgTVqps2zm4T6eWCI02btRgOInFhxqiMiKQWB4iLQb_SloKtdavY4txeZ2x0tnS8b75eeHKICvBbpxEhwmZIBgw0yU7zA6WsVceHrxlAQo2kyq5OIfDEJ7H_T9Zz7DwCTYT6xZE7d-T8irMo4ZuT4qaFiJ9mdsKJrr64rHLPLUqw1gH-KaDPJaZ3_VoxKRDIpRtxE_EU169eXE5SOvkfScZKSJjKM46EwcQ","title":"lofi hip hop radio - beats to sleep\\/relax to 😴","ldpj":"-14","partnerid":"27","apiary_host_firstparty":"","no_get_video_log":"1","afv_ad_tag":"https:\\/\\/googleads.g.doubleclick.net\\/pagead\\/ads?ad_type=skippablevideo_bumpervideo\\u0026channel=Vertical_1030%2BVertical_215%2BVertical_3%2BVertical_35%2BVertical_588%2BVertical_592%2Bafv_instream%2Bafv_instream_kr%2Bafv_user_562steezy%2Bafv_user_id_sIg9WMfxjZZvwROleiVsQg%2Bivp%2Byt_bs1%2Byt_bs2%2Byt_bumpers%2Byt_cid_13262895%2Byt_mpvid_dJmdcebwVEoFFwha%2Byt_no_ap%2Byt_no_cp%2Byt_no_wa%2Bytdevice_1%2Bytdevicever_2.20181115%2Bytel_detailpage%2Bytps_default\\u0026client=ca-pub-6219811747049371\\u0026correlator=2909199032580446479\\u0026dbp=ChZtNGpZWVh3TURMZ3BlZEYwMHktcjRnEAEgASgAOAE\\u0026description_url=http%3A%2F%2Fwww.youtube.com%2Fvideo%2Fc_IVcbEez8o\\u0026dt=1542542891148\\u0026eid=215394446\\u0026hl=ko\\u0026host=ca-yt-host-pub-5541709474267628\\u0026lact=0\\u0026loeid=9489025,23777186,23774947,23757412,23774306,23758598,23773607,23778824,23774433,9471239,9469036,23735277,23779311,23771857,9474356,23769086,23769433,23766073,23767226,9450140,23733598,9477942\\u0026lsv=1\\u0026max_ad_duration=16500\\u0026min_ad_duration=0\\u0026num_ads=1\\u0026osd=2\\u0026output=xml_vast3\\u0026pucrd=CgYIABAAGAB4Ag\\u0026sdkv=h.3.0.0\\u0026sdki=18803DFD\\u0026sdr=1\\u0026sz=640x355\\u0026t_pyv=exclude ...

# %%
total_review=[]
for k in example:
    total_review.append(re.split('동영상 채팅|동영상으로 이동|게시됨 5개월 전',k))

# %%
total_review
# Out:
# [['4:06:27',
#   '초보누에 (dksktkwl):와 진짜 꼬갓 넘넘 미쳤음 퍄퍄퍄퍄 ㅠㅠㅠㅠㅠㅠㅠㅠ 개머싯어',
#   '초보누에 (dksktkwl)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 50:45'],
#  ['4:03:52', '남천동 (smartboy1203):ㄱㅈㅁㅁ', '남천동 (smartboy1203)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 4:37:02'],
#  [' 게시 시간 33:49'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:32:48'],
#  ['3:56:55', '운타라최고다 (sogogi0816):갓구', '운타라최고다 (sogogi0816)'],
#  ['3:41:53', '귀여운아롱이 (ero100):혜지 굿~', '귀여운아롱이 (ero100)'],
#  [' 게시 시간 5:24'],
#  ['3:24:25', 'jang2031:크 엳시 동준', 'jang2031'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:04:03'],
#  ['52:48', 'IolFranco:야스오 바로리쉬중 ㅋㅋㅋ', 'IolFranco'],
#  ['1:50:19', 'arnapola:대ㅡㅡㅡㅡㅡㅡㅡ퍼', 'arnapola'],
#  ['1:14:41', '차냥한다 (t53171213):????', '차냥한다 (t53171213)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:02:15'],
#  ['4:04:25', 'naaaaamoooo:소라카도 하는거없어 왜픽함', 'naaaaamoooo'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:33:09'],
#  ['1:58:36', '마트료제시카 (matroska94):장로 미췬', '마트료제시카 (matroska94)'],
#  ['2:04:42', 'ggdog444:대퍼의 기적', 'ggdog444'],
#  ['3:52:20', 'exteriorglass:트할템머야 저거왜감', 'exteriorglass'],
#  ['4:36:30', 'wbo0622:잼구 : 던짐', 'wbo0622'],
#  ['3:55:12', '밤에피는장미란 (kyant13):뱅 점멸힐 ㅋㅋㅋ', '밤에피는장미란 (kyant13)'],
#  ['50:48', '선지쉐이크 (blessthief):대퍼타임', '선지쉐이크 (blessthief)'],
#  ['3:18:20', '제프티 (leinpols):얘들 신났네 ㅋㅋ', '제프티 (leinpols)'],
#  ['4:34:18', 'binstyle:?', 'binstyle'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:29:14'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:47:39'],
#  ['1:01:53', '누가물어봄 (factattacking):?', '누가물어봄 (factattacking)'],
#  ['29:51',
#   '급진적페미니스트김경현 (very_hot_fire_fist_gombo_):미쉐린 + 용준좌',
#   '급진적페미니스트김경현 (very_hot_fire_fist_gombo_)'],
#  ['1:31:56', 'zcxv1234:대 동 빈', 'zcxv1234'],
#  ['1:56:43', '만긍이 (rockman0810):2명이 덮쳐 ㅗㅜㅑ', '만긍이 (rockman0810)'],
#  ['2:10:52', '엔소르 (kieltre):이이이잉', '엔소르 (kieltre)'],
#  ['4:31:02', 'omh1555:싱크 개판이네', 'omh1555'],
#  ['2:14:56', '라무네 (likeingan):프로도 힘듬 ㅋㅋ', '라무네 (likeingan)'],
#  ['52:35', '침대인간 (applier):ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', '침대인간 (applier)'],
#  ['1:09:19', 'eagleeye_mincheol:뭐냐아! ㅋㅋ 스포티비', 'eagleeye_mincheol'],
#  ['2:23:42', '애비게일 (ymh708):케스팤ㅋㅋ', '애비게일 (ymh708)'],
#  ['3:55:51', 'rpcn545:진짜 재밌다 ㅋㅋㅋㅋㅋㅋ', 'rpcn545'],
#  ['3:46:54', '천연밀가루 (wnsgur3638):??', '천연밀가루 (wnsgur3638)'],
#  ['2:03:02', '톡구99 (toesu2435):그 자리', '톡구99 (toesu2435)'],
#  ['4:17:36', '돌엄니칭구 (jch618):운타라 오랜만에 보여주라', '돌엄니칭구 (jch618)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:25:09'],
#  ['3:52:33', 'jackgarba:PaoloCannone', 'jackgarba'],
#  [' 게시 시간 1:40'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:02:14'],
#  ['2:00:47', 'chunrae:근데 문도가 미드네', 'chunrae'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 4:08:09'],
#  ['4:22:08', 'CleanSound:?뭐야 킹존 이겼네 그렇게 말리고', 'CleanSound'],
#  ['4:00:21', '갈매기 (instant0530):ㅈㅈ', '갈매기 (instant0530)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:04:50'],
#  ['1:05:25', '케빈 (rjssl1007):오프닝 개머싯다 ㄹㅇ', '케빈 (rjssl1007)'],
#  ['3:53:47', 'DivaPlay:SKT 울프 왜 안씀?', 'DivaPlay'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:39:25'],
#  ['2:00:11', 'AEHYO:어제 왜 무슨일 있었음?', 'AEHYO'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:11:47'],
#  ['3:42:48', 'legendVQ:역시 세주 원챔충', 'legendVQ'],
#  ['', '4:42:17', 'beor1324:???????', 'beor1324'],
#  ['4:40:30', '다유 (jsr132):ㅈ포폴트', '다유 (jsr132)'],
#  ['2:02:17', 's4karis:그 위치', 's4karis'],
#  ['3:35:53', '닁닁낭낭 (limsor1229):어 우 슼', '닁닁낭낭 (limsor1229)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:49:49'],
#  ['2:15:34', 'gh07233:자아성찰 ㅋㅋㅋㅋㅋㅋ', 'gh07233'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:04:01'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 4:24:19'],
#  ['2:16:31', '드래곤라인 (bluvita1):스맵 여유있는척 ㅋㅋ', '드래곤라인 (bluvita1)'],
#  ['4:46:00', 'portablezerozero:퍼줬죠', 'portablezerozero'],
#  ['1:18:01', '망고샴푸 (garnetring):노모 ㄷㄷ', '망고샴푸 (garnetring)'],
#  ['4:09:22', '레이블_ (labelpaper):ㅠㅠ', '레이블_ (labelpaper)'],
#  ['52:31', '떡마귀 (rlarjsdnr100):이야 쥬시맨', '떡마귀 (rlarjsdnr100)'],
#  ['3:36:47', '김읍읍 (killignstar):투할;', '김읍읍 (killignstar)'],
#  [' 게시 시간 2:15'],
#  ['34:11', '치킨2치킨 (verve1027):리멕전임', '치킨2치킨 (verve1027)'],
#  ['47:15', 'jueun12:롤챔스 개재밌다', 'jueun12'],
#  ['4:32:47', '성문종합 (kksshv):캬', '성문종합 (kksshv)'],
#  ['1:45:29', 'Onsaemiro42:기가 막히네 ㅋㅋㅋ', 'Onsaemiro42'],
#  ['', '1:59:31', '으자 (frozen1205):엄', '으자 (frozen1205)'],
#  ['22:06', '까즈 (mgy2002):진에어 선 ㅋㅋ', '까즈 (mgy2002)'],
#  ['1:37:42', 'kinggodmperor:타잔님ㅠㅠ?', 'kinggodmperor'],
#  ['47:54', '존야를눌러 (originaljhon11):즈엉상인데', '존야를눌러 (originaljhon11)'],
#  ['54:50', '마늘맛사탕 (mymaks682):갓갓갓갓', '마늘맛사탕 (mymaks682)'],
#  ['44:16', '살상인 (kolin136):레넥기한 ㅈㅈ', '살상인 (kolin136)'],
#  ['57:31', '채팅안침 (kxv257):이제 도파가 전화로 피드백해준다 ㅋㅋ', '채팅안침 (kxv257)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:21:08'],
#  ['3:19:14', '솔라리스 (sinhyg1):운타라가 발전좀 하지', '솔라리스 (sinhyg1)'],
#  ['4:01:04', '공기극딜 (spekdma):킹 갓 혜지 + 트할머니보쌈', '공기극딜 (spekdma)'],
#  ['1:01:04', 'A1ba27:1세트 누가땀', 'A1ba27'],
#  ['4:05:24', '마츠브 (jy970813):원딜 소라카ㅋㅋㅋㅋㅋ', '마츠브 (jy970813)'],
#  ['4:17:35', '혀낙이 (jar5382):나도 안맞음', '혀낙이 (jar5382)'],
#  ['3:56:38', 'salromanchicken:ㅋㅋㅋㅋㅋ', 'salromanchicken'],
#  ['3:34:35', '단탈리아묘아 (2retty2):소라카 봇은 뭔뎈ㅋㅋㅋㅋㅋㅋ', '단탈리아묘아 (2retty2)'],
#  ['4:40:35', '방소상 (bangsosang):대대퍼타임', '방소상 (bangsosang)'],
#  ['4:45:30', '나쎄존 (ddmina):풉', '나쎄존 (ddmina)'],
#  ['4:18:43', '못이기 (cant_victory):고 멘', '못이기 (cant_victory)'],
#  ['4:26:20', '안녕하시나요선생님들 (kms423):이즈로 스웨인 절대못잡는데', '안녕하시나요선생님들 (kms423)'],
#  ['2:00:04', 'zmrsl:대퍼라서 모른다', 'zmrsl'],
#  ['1:31:44', "이겜해보고싶어 (geeasdf):이게 바로 '국가대표'다", '이겜해보고싶어 (geeasdf)'],
#  ['1:09:59', '싫은날 (cocopopp6714):kt가 잘 준비했네', '싫은날 (cocopopp6714)'],
#  ['1:39:13', 'minimaxmized:바람의 전학생인가', 'minimaxmized'],
#  ['55:32', '꼬마티슈 (asmona):신고식담당', '꼬마티슈 (asmona)'],
#  ['4:40:59', '항상조심해 (xzc325):에포트 진짜 노답', '항상조심해 (xzc325)'],
#  ['3:29:52', 'rlatjdxo3cm:슼이 그냥 이기겠네 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', 'rlatjdxo3cm'],
#  ['1:33:43', 'qlqh9090:ㅁㅠ', 'qlqh9090'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:24:09'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:05:06'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:52:10'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 27:34'],
#  ['3:55:11', '조제해적단 (kgoku648):개재밋네 진짜로 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', '조제해적단 (kgoku648)'],
#  ['3:49:35', 'lafion:잼구 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', 'lafion'],
#  ['48:54', '현쓰훈트 (dongsk89):ㅋㅋㅋㅋㅋㅋㅋㅋㅋ용카이팅', '현쓰훈트 (dongsk89)'],
#  ['41:16', 'jihaes2:이대로가면 그리핀이 중국 씹발라주려나', 'jihaes2'],
#  ['50:48', '에버다이 (whgusdnr1984):대퍼타임', '에버다이 (whgusdnr1984)'],
#  ['1:13:24', '_이타카 (wjswkdrms7):아트를 안하고?', '_이타카 (wjswkdrms7)'],
#  ['1:47:30', '얼어붙은왕국의룩공얍 (carta987):아 진짜 개웃기네 ㅋㅋㅋㅋㅋ', '얼어붙은왕국의룩공얍 (carta987)'],
#  ['38:56', '닿기를 (rhrnfu2002):알파카 본체 나왔다.', '닿기를 (rhrnfu2002)'],
#  ['1:03:39', '합스부르그 (kjh8207):왜 모닝임? 오후 경기 아님?', '합스부르그 (kjh8207)'],
#  ['2:10:50', 'Sweetsay:이이이잉', 'Sweetsay'],
#  ['1:57:49', 'draliay:한타의 KT', 'draliay'],
#  ['21:33', '잘됐으면좋겠다 (gkdltlzj):ㄷㄷ', '잘됐으면좋겠다 (gkdltlzj)'],
#  ['1:46:00', '따워 (rktower010):다리우스 궁 계속 박는거봐라 ㄷㄷ', '따워 (rktower010)'],
#  ['2:16:02', '문별이_ (yooa0917):패기좋노', '문별이_ (yooa0917)'],
#  ['3:59:10', '큰빛나리 (kth0070722):ㅁㅁ', '큰빛나리 (kth0070722)'],
#  ['2:00:10', '공식 (tlqpffjadk1):ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', '공식 (tlqpffjadk1)'],
#  ['3:43:42', '튜비 (wnrks12):갓구 떡상 왓다', '튜비 (wnrks12)'],
#  ['', '53:59', '우닭이 (wallgung):미드이렐은 똥이다.', '우닭이 (wallgung)'],
#  ['2:18:21', '서네서네 (tjstjs55):전패는 있다!', '서네서네 (tjstjs55)'],
#  ['4:46:01', 'wer3162:오 문도 ㅋ', 'wer3162'],
#  ['1:36:47', '에버다이 (whgusdnr1984):용컨 ㄲㅂ', '에버다이 (whgusdnr1984)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:15:28'],
#  ['3:39:46', 'c2212:갓구', 'c2212'],
#  ['3:34:02', 'dfcxz:롤 실화냐??', 'dfcxz'],
#  ['4:24:53', '아리폰 (aripon):팀 솔로 미드!!!!!', '아리폰 (aripon)'],
#  ['3:46:03', '희섭 (khsdfg952):판정 오반데?', '희섭 (khsdfg952)'],
#  [' 게시 시간 32:56'],
#  ['3:59:06', '신세카이 (mlb5021):플 뺏다', '신세카이 (mlb5021)'],
#  ['3:16:41', '차캐요 (baksick2):나 왜 갑자기 싱크 안맞지', '차캐요 (baksick2)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 24:30'],
#  ['1:26:09', '_이타카 (wjswkdrms7):왜 여기는 바위게 먹은 횟수 안뜸?', '_이타카 (wjswkdrms7)'],
#  ['2:09:14', '아랏따 (kkrbng):그리핀 왜 졋냐 ㅋㅋㅋ', '아랏따 (kkrbng)'],
#  ['3:42:56', '소금맛설탕 (rlathfrl12):004 ㄷㄷㄷㄷㄷ', '소금맛설탕 (rlathfrl12)'],
#  ['3:19:07', '프카 (ehdtkdhkd):에포트 잘나왔네', '프카 (ehdtkdhkd)'],
#  ['24:34', '갤러거 (mugulchrome):쉔밴 맞지', '갤러거 (mugulchrome)'],
#  ['1:17:30', '블루쵸파 (bluechopa):바이퍼가 할게 너무 없당', '블루쵸파 (bluechopa)'],
#  ['3:24:44', 'k1dl3ad3r:킹존 승 !', 'k1dl3ad3r'],
#  ['3:25:01', 'little8oy:페이커만 막으면 스크는', 'little8oy'],
#  ['2:26:10', 'yabby:ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ이것은', 'yabby'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:51:11'],
#  ['4:34:14', 'cho10987:시간 개손해아닌가', 'cho10987'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:15:03'],
#  ['3:44:46', 'sonete77:와드', 'sonete77'],
#  [' 게시 시간 20:51'],
#  ['4:28:09', 'zoqxlsgh:뚜벅이 조합이냐? ㅋㅋ', 'zoqxlsgh'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:41:01'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:51:27'],
#  ['1:15:47', 'golizerd:1위를 #뒤집어버려 kt (korea team)스코어도 2대 0', 'golizerd'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:53:29'],
#  ['4:29:35', '똥개래 (gotjrdl11):뱅기 ㅜ', '똥개래 (gotjrdl11)'],
#  ['4:33:39', '김과일 (ksdo3923):ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', '김과일 (ksdo3923)'],
#  ['3:55:29', '직업트수 (mylife_for_twitch):뱅크드 바이 맘', '직업트수 (mylife_for_twitch)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:05:17'],
#  ['3:48:38', 'Spvls0613:잼구 ;;', 'Spvls0613'],
#  ['1:36:19', '장서켠 (koover4):케이티는 폰 버린게 신의한수임', '장서켠 (koover4)'],
#  ['1:31:49', '담백한버터 (toyou35):ㅋㅋㅋㅋㅋ', '담백한버터 (toyou35)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:27:00'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 4:01:31'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:07:08'],
#  ['1:45:14', 'sg01312:한타의 그리핀 ㅅㄱ', 'sg01312'],
#  ['54:03', '콜라쫌 (woosung0123):ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 그 귀환', '콜라쫌 (woosung0123)'],
#  ['4:33:52',
#   '시바리수 (xkdlrj010):ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#   '시바리수 (xkdlrj010)'],
#  ['3:40:39', 'gkswngjs12:칸무룩', 'gkswngjs12'],
#  ['2:04:12', '왼잽이 (jyi1328):담당일진', '왼잽이 (jyi1328)'],
#  ['4:12:52', '루티엘 (catcrawn):갓프닝', '루티엘 (catcrawn)'],
#  ['1:58:45', '당근순 (mj4421):슈ㅡㅡ퍼', '당근순 (mj4421)'],
#  ['47:25', 'kspc2:5인도발 미쳤어', 'kspc2'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:20:04'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:43:35'],
#  ['2:16:00', 'JoYuneHo:벌써 2000년대 생들 나오네', 'JoYuneHo'],
#  ['4:03:59', '귀족갈비 (thsdydgus123):도도갓...', '귀족갈비 (thsdydgus123)'],
#  ['1:59:02', 'cravenimp:이속봐 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', 'cravenimp'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 48:52'],
#  ['3:15:16', '은신님_ (heyolock):Bengi ㄷㄷㄷㄷ', '은신님_ (heyolock)'],
#  ['3:54:32', '김소혜 (lhj0103kr):폐', '김소혜 (lhj0103kr)'],
#  ['54:54', '햄스터 (windec22):쥬시하라', '햄스터 (windec22)'],
#  ['4:26:34', '월계수나무 (amg1682):아 제발', '월계수나무 (amg1682)'],
#  ['2:15:51', '팬더머가리 (www3493):저 얼굴이 2001년...?', '팬더머가리 (www3493)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:31:17'],
#  ['46:48', 'o0o0o0:유칼 쩔ㄹ었땈ㅋㅋㅋ', 'o0o0o0'],
#  ['3:30:32', 'sang99246:구와악', 'sang99246'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 4:28:39'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:48:01'],
#  ['1:51:58', 'ycjj:모렐로있는데 ㅁ?', 'ycjj'],
#  ['1:07:49', '엑스펙스 (bydream11):크', '엑스펙스 (bydream11)'],
#  ['3:44:33', 'veresk777:', 'veresk777'],
#  [' 게시 시간 27:59'],
#  ['59:08', '엘리트마법가루 (wietle):머 주시하라만 하면 다 죽네', '엘리트마법가루 (wietle)'],
#  ['29:24', '클로렐라쌀밥 (whtlaehd123):초ㆍ비 야스오도 잘하던데', '클로렐라쌀밥 (whtlaehd123)'],
#  ['50:49', 'dhkim1268:대퍼타임마', 'dhkim1268'],
#  [' 게시 시간 31:26'],
#  ['2:04:58', 'ai234:담당 일진 ㅋㅋㅋ', 'ai234'],
#  ['1:53:17', '스졸렬 (mlli1412):데프트 ㅋㅋ', '스졸렬 (mlli1412)'],
#  ['1:36:05', '외가 (aorbint56):누강 강팀인지 알수 없게 되어버린 개족보가 된거지..', '외가 (aorbint56)'],
#  ['3:15:13', 'deuxmj123:이거 노래 머임???', 'deuxmj123'],
#  [' 게시 시간 14:35'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:08:15'],
#  ['3:46:17', '갈릭버터맛우결충 (kphsws):혜지가 미쳤네 갑자기?', '갈릭버터맛우결충 (kphsws)'],
#  ['1:50:18', 'shangus01:대ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ퍼', 'shangus01'],
#  ['4:18:02', '엉덩이안의정의 (zazaxs):ogn 사내 커뮤니티', '엉덩이안의정의 (zazaxs)'],
#  ['4:03:24', '트위퍼 (vert_pomme):ㅈㅈㅈ', '트위퍼 (vert_pomme)'],
#  ['1:10:49', 'nadajun1:용준좌 실성', 'nadajun1'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:33:19'],
#  ['1:07:56', '자칼54 (na6game):빛코어 수듄', '자칼54 (na6game)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:22:44'],
#  ['3:59:28', '깜오 (magi19238):이게 귀환이지', '깜오 (magi19238)'],
#  ['4:42:19', 'cakeisspy123:뭐함', 'cakeisspy123'],
#  [' 게시 시간 5:55'],
#  ['3:39:43', 'SINISE77:킹구', 'SINISE77'],
#  ['4:09:49', 'qkdldhslzjf:ㅁㅊ 브금 ㅋㅋㅋㅋㅋㅋㅋ', 'qkdldhslzjf'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:52:14'],
#  ['1:00:06', '다임구혁 (gurdyd9):으앜!!!!!!!', '다임구혁 (gurdyd9)'],
#  ['21:36', 'goodchu:황 비 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ', 'goodchu'],
#  ['3:50:15', '나랑빠데하카 (wbsldjalswo):18섬머 세체미는 이안이다..', '나랑빠데하카 (wbsldjalswo)'],
#  ['4:18:21', '핵뚠뚠 (hogcat_):ㅇㅈ 경기 꿀잼이었다', '핵뚠뚠 (hogcat_)'],
#  ['3:37:30', '송용준의오른손 (ckd227):블랭크개트롤ㅇ네진짜', '송용준의오른손 (ckd227)'],
#  ['4:04:59', '우물이 (ssimsangi):미드 개못함', '우물이 (ssimsangi)'],
#  ['2:12:59', '쫑그 (gyu05303231):다나까ㄷㄷㄷㄷ', '쫑그 (gyu05303231)'],
#  ['3:34:49', 'zmfl1234:듣보', 'zmfl1234'],
#  [' 게시 시간 0:25'],
#  ['1:59:27', 'gks414:무몬뎈ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', 'gks414'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:02:21'],
#  ['4:33:35', '성적호기심 (sup8072):표정ㅋㅋㅋㅋㅋㅋㅋㅋㅋ', '성적호기심 (sup8072)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 45:24'],
#  ['3:47:30', '욕망덩어리 (yogmang):소라카????', '욕망덩어리 (yogmang)'],
#  ['1:12:46', 'goewon:무신 젠지냐', 'goewon'],
#  ['3:59:22', '크보후퇴 (then2f):혜지야 너 잘하고 있어!', '크보후퇴 (then2f)'],
#  ['1:07:39', '0unG0101:야그라미 갓살표 ㄷㄷ', '0unG0101'],
#  ['52:21', 'hakodate777:야소 리폿좀', 'hakodate777'],
#  ['1:07:08', 'buffadpls231:쥬시하라', 'buffadpls231'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:49:28'],
#  ['32:42',
#   '싹둑 (ssakdook):2018 LoL 챔피언스 코리아 섬머 : 6월 12일 ~ 7월 1일 / 7월 11일 ~ 8월 2일 / 8월 4일~ 8월 9일 ▣ 매주 월요일 휴무',
#   '싹둑 (ssakdook)'],
#  ['1:50:29', 'sh6563:문도가 진짜 혐도다혐도;;;;;;;;;;;', 'sh6563'],
#  ['1:51:19', '뭐되더놈 (illegalp1):이걸 대퍼하네', '뭐되더놈 (illegalp1)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:10:55'],
#  ['28:29', '테일러 (bp_tailor):바이퍼 라이즈 나오나?', '테일러 (bp_tailor)'],
#  ['2:58:33', 'nowrock59:어디 해설인가여', 'nowrock59'],
#  ['4:27:39', 'helloalone:ㅈㅈ', 'helloalone'],
#  ['3:30:05', '우노_우노 (skadbsgh123):ㄷㄷ?', '우노_우노 (skadbsgh123)'],
#  ['4:34:22', '제로콜 (c0cac0lazer0):ㅋㅋㅋㅋㅋ', '제로콜 (c0cac0lazer0)'],
#  ['52:31', '말리킴 (yooni0819):와 미쳤다 ㅋㅋㅋㅋㅋㅋㅋ', '말리킴 (yooni0819)'],
#  ['3:42:38', 'fullinlove486:슼 대승리 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', 'fullinlove486'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:43:56'],
#  ['3:19:42', 'k1dl3ad3r:LLLLLLLLLLLLLLL', 'k1dl3ad3r'],
#  ['2:31:51', 'roh468:네 그리핀이 이김', 'roh468'],
#  ['1:10:15',
#   '트위치마니보는사람 (twitchjoaing):신입생 폭격기 무엇',
#   '트위치마니보는사람 (twitchjoaing)'],
#  ['23:55', '우리형이야왜그래 (nionhar):띵장', '우리형이야왜그래 (nionhar)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 4:34:01'],
#  ['4:15:49', 'ingyu_mom:패슼슼 가즈아~!!!!', 'ingyu_mom'],
#  ['31:10', 'nhlh7l:겨털노출', 'nhlh7l'],
#  ['3:44:05', 'kissmac:칸 꽁으로 한번살고 3데스', 'kissmac'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:09:30'],
#  ['1:43:14', 'IDandyAndyI:대ㅡ퍼', 'IDandyAndyI'],
#  ['1:59:26', '엉덩방개 (audrn156):아 광고 진짜 젼나많네 들어올때마다 있네', '엉덩방개 (audrn156)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:32:45'],
#  ['3:42:54', '풍댕이엉댕이 (tkdkr12):ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', '풍댕이엉댕이 (tkdkr12)'],
#  ['4:39:34', 'dkffkels482:형들ㅋㅋㅋㅋㅋㅋㅋㅋ', 'dkffkels482'],
#  ['37:16', 'kangjw0403:8.12', 'kangjw0403'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:37:49'],
#  ['1:01:09', 'zmrzmzmr:진짜 딱 매123갈들이나 쿰123척거리면서 좋아하겠네 ㅋㅋ', 'zmrzmzmr'],
#  ['2:18:26',
#   '조강현은모두의것이니까요 (joganghyun_is_everybody_s):킅트와 슼트 무너졌네',
#   '조강현은모두의것이니까요 (joganghyun_is_everybody_s)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:19:05'],
#  ['2:01:16', 'east_tiger:슈---퍼팀', 'east_tiger'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:11:11'],
#  ['50:48', '이제원 (jwlee04231):대퍼타임ㅋㅋ', '이제원 (jwlee04231)'],
#  ['2:27:15', '리롱띠 (tkdlgk1):앗..아아 스코어', '리롱띠 (tkdlgk1)'],
#  ['4:08:13', '동원마일드참치 (hdlee2312):구와앜', '동원마일드참치 (hdlee2312)'],
#  ['4:45:51', '망고샴푸 (garnetring):트할 4킬 먹고시작했는데 왜이리됐냐?', '망고샴푸 (garnetring)'],
#  ['4:42:43', 'adoong00:550', 'adoong00'],
#  ['1:59:31', '징쥥 (tgi1213):엄?', '징쥥 (tgi1213)'],
#  ['3:46:57', '전찬 (jjj5530):까비', '전찬 (jjj5530)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 4:16:48'],
#  ['57:45', '돚거입니다 (nkh0417):도파충 좀 ㄲㅉ라', '돚거입니다 (nkh0417)'],
#  ['3:24:05', 'o0o0o0:형모야 부탁해', 'o0o0o0'],
#  ['3:58:00',
#   '프리즈비슬라이더 (youna40):트할은 진짜 뜬금사 좀 어떻게 피드백 안되냐? 맨날 혼자 죽어 아놔....',
#   '프리즈비슬라이더 (youna40)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:14:42'],
#  ['3:51:07', '저급어그로 (ekekr):왜 깝침 ㅋㅋ', '저급어그로 (ekekr)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:33:15'],
#  ['2:16:56', 'cactusstick:ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', 'cactusstick'],
#  ['4:33:55', '행복수비 (crazyzerg2):나라잃은 표정', '행복수비 (crazyzerg2)'],
#  ['49:08',
#   '체력왕김피곤 (badboy9467):아무리 그리핀이라도 이건 힘들다 진심 ㅋㅋㅋㅋ',
#   '체력왕김피곤 (badboy9467)'],
#  ['4:16:52', '민딘이 (dlrcoel):저거 지분 트할7 블랭크3 ㅇㅇ', '민딘이 (dlrcoel)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 56:25'],
#  ['4:07:31',
#   '히바나온나나 (rrribbit0805):1+1 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#   '히바나온나나 (rrribbit0805)'],
#  ['53:57', '메이플좋아 (koreakso):그 귀환 ㅋㅋㅋ', '메이플좋아 (koreakso)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:45:48'],
#  ['4:44:39', '혀낙이 (jar5382):싱크이상함', '혀낙이 (jar5382)'],
#  ['2:58:46', 'nowrock59:오 굳', 'nowrock59'],
#  ['1:37:25', "방송좀잘해봐 (zz930128):'그' 리핀", '방송좀잘해봐 (zz930128)'],
#  ['1:31:51', '알라인 (allein94):스고수~', '알라인 (allein94)'],
#  ['1:10:42', '영재짱1 (poweryj):ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', '영재짱1 (poweryj)'],
#  ['3:37:20', 'Freyja738:트할잘못임', 'Freyja738'],
#  ['2:00:13',
#   '룩삼_쪼아 (looksam_jjoa):전반은 못봤지만 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#   '룩삼_쪼아 (looksam_jjoa)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:21:19'],
#  ['2:03:09', '데코즈 (decoz91):근데 오늘 그리핀은 왜 이리 픽을 불리하게 뽑지', '데코즈 (decoz91)'],
#  ['1:31:47', '코노스바우주명작 (ljyong0303):국 대 정 글', '코노스바우주명작 (ljyong0303)'],
#  ['3:20:10', '넥스트 (nagihara):커즈는 나온적이 없어서 저런가', '넥스트 (nagihara)'],
#  [' 게시 시간 12:20'],
#  ['1:59:00', '지나가는지렁이 (holicoo):korean team win', '지나가는지렁이 (holicoo)'],
#  ['38:37', '망고베리 (hyuuunj):d', '망고베리 (hyuuunj)'],
#  ['1:55:54', 'apane12aa:클피셜) 그리핀>>KT', 'apane12aa'],
#  ['2:03:05', 'kangjw0403:마따 머합니까?', 'kangjw0403'],
#  ['3:35:54', 'silver1429:띠용 비디디 왜 저깄음', 'silver1429'],
#  ['4:32:51', '브래포드 (fnstmzkdl12):페이커 ㅠㅠㅠㅠ', '브래포드 (fnstmzkdl12)'],
#  ['1:00:48', '범닭 (gg9185):이거 2~3세트 하루나와서 젠지가 이김', '범닭 (gg9185)'],
#  ['2:15:30', '포장용아이스팩 (raum_9114):ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', '포장용아이스팩 (raum_9114)'],
#  [' 게시 시간 0:20'],
#  ['3:19:06', '홍방귀 (ysj991105):전력?', '홍방귀 (ysj991105)'],
#  [' 게시 시간 3:37'],
#  ['3:42:45', '서폿빼고다갑니다 (harrybbwe):갓구나이트', '서폿빼고다갑니다 (harrybbwe)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:38:30'],
#  ['3:34:21', '물약자판기 (ileisamsa):     ', '물약자판기 (ileisamsa)'],
#  ['3:37:13', '장4장 (jang4jang):트할 뭐하냐', '장4장 (jang4jang)'],
#  ['4:17:25', 'kimdj342:블랭크가 뭘 망침', 'kimdj342'],
#  ['55:03', '김씨닷 (kimcdot128):담당일진 ㄹㅇ류', '김씨닷 (kimcdot128)'],
#  ['3:45:37', '쿠라란 (albanlid):아깝다 그 귀환', '쿠라란 (albanlid)'],
#  ['', '4:38:49', 'jang2031:그래 잼구야 뭐 이상한거 하지말고 걍 용 먹어라', 'jang2031'],
#  ['23:47', '모케 (hollowpiece):kt팬 많을건데 걍 찍어눌럿네', '모케 (hollowpiece)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:33:57'],
#  ['2:27:05',
#   '나에게키보드만있었더라면 (qwerty_asdfgh_zxcv_steelo):페이커 깜짝 출현 ㅋㅋㅋㅋ',
#   '나에게키보드만있었더라면 (qwerty_asdfgh_zxcv_steelo)'],
#  ['1:00:21', 'k000ooo:큐베 간큰거 보소', 'k000ooo'],
#  ['3:32:37', 'iris21c:소라카원딜?', 'iris21c'],
#  ['2:18:05', 'Chamring:2대떡', 'Chamring'],
#  ['4:40:30', '슬렛 (kjy14224):개싸움ㅋㅋㅋㅋㅋ', '슬렛 (kjy14224)'],
#  ['1:42:43', 'meanprize:??', 'meanprize'],
#  ['4:36:58', '할거없긔 (ijhijh78):또간다', '할거없긔 (ijhijh78)'],
#  ['2:05:00', 'buffadpls231:그리핀 하위팀', 'buffadpls231'],
#  [' 게시 시간 12:52'],
#  ['1:15:02', 'goewon:다주냐', 'goewon'],
#  ['46:26', '슬리퍼는삼디다스 (hmc9909):JUICY 하라', '슬리퍼는삼디다스 (hmc9909)'],
#  ['3:46:19', 'plus3631:바텀차이진짜어마어마하다', 'plus3631'],
#  [' 게시 시간 12:14'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:54:18'],
#  ['1:50:44', '티모장인 (sky0331):문도 무적 ㅋㅋㅋㅋ 개사기 ㅋㅋㅋㅋㅋ', '티모장인 (sky0331)'],
#  ['19:54', '올란두 (zialng):그리핀 1패 누가 만들어줄까?', '올란두 (zialng)'],
#  ['4:34:20', '침대위의메르시 (mercy_on_the_bad):ㅋㅋㅋㅋㅋ', '침대위의메르시 (mercy_on_the_bad)'],
#  ['3:36:41', 'Spvls0613:?', 'Spvls0613'],
#  ['1:48:50', 'kisalute:각.개.전.투', 'kisalute'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 4:23:55'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 4:40:45'],
#  ['1:00:10', '설뤼반 (ddholic):프레이는 가장도 아닌데 왜그러는거냐...', '설뤼반 (ddholic)'],
#  [' 게시 시간 18:30'],
#  ['4:24:03', '포케모온마스또 (ehs57111):3:3임?', '포케모온마스또 (ehs57111)'],
#  ['3:31:05', 'dreaming9436:이게 전략겜이지', 'dreaming9436'],
#  ['4:33:37', '고래구마 (baleine532):ㅋㅋㅋㅋㅋㅋㅋ', '고래구마 (baleine532)'],
#  ['3:46:53', '나의주 (denebollacan):서폿차이가 좀심하긴하네', '나의주 (denebollacan)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:13:02'],
#  ['3:54:24', '아네모 (yujining0628):소리 싱크 왜이러지', '아네모 (yujining0628)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 4:03:48'],
#  ['3:40:31', 'extracter1:갓구나이트;;', 'extracter1'],
#  ['1:46:58', 'vqhtm12:초비 조이는 필밴이여', 'vqhtm12'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:52:01'],
#  ['4:40:35', 'msj98:ㅋㅋㅋㅋㅋㅋㅋㅋㅋ', 'msj98'],
#  ['3:43:37', '신구__02 (singu__02):킹갓제너럴갓구', '신구__02 (singu__02)'],
#  ['4:00:47', '버퍼링좀고쳐줘 (whwns3521):그건좀', '버퍼링좀고쳐줘 (whwns3521)'],
#  ['27:08', '오늘밥은치킨 (a991213):ㅡ스', '오늘밥은치킨 (a991213)'],
#  ['1:16:06', '긍정멘탈소환사 (johanhee7):쵸비의 조이라면 ㄹㅇ 믿을 만 하지', '긍정멘탈소환사 (johanhee7)'],
#  ['4:02:52',
#   '힘내라너구리 (mybee1208):소라카 침묵즉잘이 좋아서 쓰는건데 이건 너무 쎄서 의미가 없어졌넹..',
#   '힘내라너구리 (mybee1208)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 4:29:55'],
#  ['1:42:40',
#   '나에게키보드만있었더라면 (qwerty_asdfgh_zxcv_steelo):??',
#   '나에게키보드만있었더라면 (qwerty_asdfgh_zxcv_steelo)'],
#  ['3:30:35', 'rkaak33:라칸 정글이야?', 'rkaak33'],
#  ['2:29:32', 'whrtldn90:빠따', 'whrtldn90'],
#  ['1:02:13', 'H4ZE33:한화스폰ㅋㅋㅋㅋㅋ', 'H4ZE33'],
#  ['3:18:32', 'jang2031:헐 커즈 나왔으면 슼 졌네 ㅠㅠ', 'jang2031'],
#  ['4:32:55', 'kangksh123:오늘갓구...', 'kangksh123'],
#  ['3:42:09', '돼지를보면짖는개 (nuri489):이펙트 보인것 같은데', '돼지를보면짖는개 (nuri489)'],
#  ['1:19:00', '원앙이 (kof9494):크트 밴픽 너무 잘햇는데?', '원앙이 (kof9494)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:38:59'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:21:10'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 4:09:58'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:57:26'],
#  ['3:55:03', 'jih675:페이커는 페이커다', 'jih675'],
#  ['4:10:28', '웡석 (jws0356):비가 많이 온다..', '웡석 (jws0356)'],
#  ['1:41:31', 'Kimwoori:ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', 'Kimwoori'],
#  ['4:32:55', 'adoong00:갓구', 'adoong00'],
#  ['21:33', 'ccc3274:이게 뭐야', 'ccc3274'],
#  ['', '2:26:15', 'JHPSoft:ㅠㅠ', 'JHPSoft'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 45:05'],
#  ['4:47:13', '차캐요 (baksick2):에포트 cs 안주네 ㅋㅋ', '차캐요 (baksick2)'],
#  ['3:47:43', 'SmRIa:오또케 오또케', 'SmRIa'],
#  ['3:49:02', '노말박 (wjdalsqkr):우리혁', '노말박 (wjdalsqkr)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:25:35'],
#  ['33:18', 'ZXC3787:잼리오 개꿀잼', 'ZXC3787'],
#  ['1:56:35', 'gino9940:태양을 등진곳에서...', 'gino9940'],
#  ['', '3:34:40', 'rkaak33:이럴거면 자기 잘하는 챔 골라서 라인스왑하면 되는거 아니냐', 'rkaak33'],
#  ['1:53:03', 'one141:kt 승 패패 ㅋㅋㅋㅋㅋ', 'one141'],
#  ['4:00:30', 'allru:트할던지네 ㅋㅋㅋㅋㅋ', 'allru'],
#  ['3:46:01', 'beautea37:떡락', 'beautea37'],
#  ['3:51:06', '천칭별 (pjh71042002):ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', '천칭별 (pjh71042002)'],
#  ['2:11:56', 'FLV_Spirit:ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', 'FLV_Spirit'],
#  ['4:06:19', '2215:벤픽이 망했음', '2215'],
#  ['3:34:51', '노빈손 (sakura605):와 고릴라', '노빈손 (sakura605)'],
#  ['3:50:32', '앙앙이요 (lcspolo):페이커 궁키고 q 맞고 딜로스 실화? 풉ㅋ', '앙앙이요 (lcspolo)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:53:02'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:50:32'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:17:29'],
#  ['2:15:41', '예술은길고 (pak0120):체 ㅡ 득', '예술은길고 (pak0120)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:47:14'],
#  ['4:20:45', 'wugef:페이커속마음) 아 팀운,,,', 'wugef'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 4:47:15'],
#  ['1:47:30', 'msj6278:한타의 대퍼', 'msj6278'],
#  ['3:46:59', '예솔이 (sdf045):고ㅡ멘', '예솔이 (sdf045)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 45:18'],
#  ['58:04', 'ath2:zzz', 'ath2'],
#  ['1:10:59', 'holy1026:부장님', 'holy1026'],
#  ['1:50:20', '항문궤양 (pmin5432):킹도 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ', '항문궤양 (pmin5432)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 4:34:52'],
#  ['30:39', 'hmhee07:근육돼지들대결', 'hmhee07'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:40:54'],
#  ['58:05', 'mircle94:다이겼는데 거품이래 ㅋㅋ', 'mircle94'],
#  ['1:22:43', '과몰입씹가능 (ssg1994):리쉬 ㄱㅅ', '과몰입씹가능 (ssg1994)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 4:00:12'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 19:39'],
#  ['2:19:50', '날좋아하는거알아 (mck9191):리라정도는 LCK 8위선에서 해결되지', '날좋아하는거알아 (mck9191)'],
#  ['3:29:29', 'remind2017:닷지유도', 'remind2017'],
#  ['2:24:38', '킴민2 (rlatmdals101):누가이겼나요?', '킴민2 (rlatmdals101)'],
#  ['1:51:12', 'Wlgh2022:ㅂ똥칼 ㅋㅋㅋㅋㅋㅋㅋㅋ', 'Wlgh2022'],
#  ['1:05:04', '코노스바우주명작 (ljyong0303):더 정 글 사 마 ㅠ', '코노스바우주명작 (ljyong0303)'],
#  ['1:10:38', 'lee99082:아...', 'lee99082'],
#  ['3:57:20', '문디멩뿌아 (koo02208):이거 무슨 핑퐁입니까? 에포트 제물입니까?', '문디멩뿌아 (koo02208)'],
#  ['55:35', '도사전우치 (toriljs):도장깨기는 끝낫나?', '도사전우치 (toriljs)'],
#  ['4:00:07', 'sw13mmer:고릴라이프 화이팅', 'sw13mmer'],
#  ['3:51:47', 'prayfor3:재밌다ㅋㅋ', 'prayfor3'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:01:54'],
#  ['4:26:36', 'skun35:또리우스 ㅋㅋ', 'skun35'],
#  ['1:58:37', 'rpcn545:캬 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ', 'rpcn545'],
#  ['2:02:08', '심이부러진연필 (hsy4428):유도 ㅋㅋ', '심이부러진연필 (hsy4428)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:56:34'],
#  ['4:29:06', 'naaaaamoooo:밴픽 부터 졌어.... 뭐하냐', 'naaaaamoooo'],
#  ['53:12', '담흑 (leesu1012):ㅋㅋㅋㅋㅋㅋㅋㅋㅋ', '담흑 (leesu1012)'],
#  ['4:27:03', '민트랑 (imoa1123):신짜오 ㅠㅠ', '민트랑 (imoa1123)'],
#  [' 게시 시간 7:17'],
#  ['3:44:22', 'xhfldjq:잼구', 'xhfldjq'],
#  ['4:29:49', '따옥 (checkclean):ㅋㅋ', '따옥 (checkclean)'],
#  ['3:59:42',
#   '싹둑 (ssakdook):▣ 채팅방 상황에 따라 슬로우 모드 적용이 이루어질 수 있습니다. ▣ 비속어 및 도배 등에 대해서는 필터링이 진행 중이니 매너 채팅 부탁드립니다. (_ _) ▣',
#   '싹둑 (ssakdook)'],
#  ['1:58:21', '카레다음깍두기 (curry5939):케넨궁 속이시원하네~', '카레다음깍두기 (curry5939)'],
#  ['4:01:48', 'r_e_m_u:소라카 1위 ㅋㅋㅋ', 'r_e_m_u'],
#  ['4:00:33', 'kingjongwoo:페이커 뭐함 ㅋㅋㅋㅋㅋ', 'kingjongwoo'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:21:50'],
#  ['', '1:45:07', 'audtjr44:대 퍼', 'audtjr44'],
#  ['57:06', 'golizerd:#뒤집어버려', 'golizerd'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:48:59'],
#  ['3:27:02', '먼지탱이2 (kyj3891):어쩌라고요', '먼지탱이2 (kyj3891)'],
#  [' 게시 시간 10:00'],
#  ['4:11:33', '우리형이야왜그래 (nionhar):킹존이 이겻다', '우리형이야왜그래 (nionhar)'],
#  ['4:38:14', '공익따무새 (gongikdda):앗 cs', '공익따무새 (gongikdda)'],
#  ['1:46:24', '타마냥 (dltjdqja726):잼이', '타마냥 (dltjdqja726)'],
#  ['45:31', '트위치마니보는사람 (twitchjoaing):ㅁㅊ', '트위치마니보는사람 (twitchjoaing)'],
#  ['1:37:38', 'erd5396:대퍼했다', 'erd5396'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:26:10'],
#  ['46:08', '차캐요 (baksick2):저걸 기어코잡네 ㅋㅋ', '차캐요 (baksick2)'],
#  ['1:53:53', 'skwmghkdud47:이게 해설이지', 'skwmghkdud47'],
#  ['2:18:48', '파반느 (dengo2611):STK T8', '파반느 (dengo2611)'],
#  ['3:21:40', '당황마침착해 (hahazic):요즘도 얼굴로 겜하나', '당황마침착해 (hahazic)'],
#  ['2:02:19', 'givemetip:녹턴밴 안한게 이렇게', 'givemetip'],
#  ['2:07:37', 'qlqh9090:스고수 하이라이트', 'qlqh9090'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 47:54'],
#  ['3:48:41', '곰대장 (bong5632):잼구 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', '곰대장 (bong5632)'],
#  ['3:41:18', '서쉘 (sershell12):그리핀 0:2로 졌어요', '서쉘 (sershell12)'],
#  ['4:00:40', '단_화 (l2o2):?', '단_화 (l2o2)'],
#  ['4:01:33', 'sinc1029:으 토나온다 트할에포트 둘이 완전 설사폭풍', 'sinc1029'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:42:36'],
#  ['3:35:33', '클로델 (timeslip05):bddㅋㅋㅋㅋ', '클로델 (timeslip05)'],
#  ['1:53:23', '헷지입니다 (kimse1005):혐-도', '헷지입니다 (kimse1005)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:34:16'],
#  ['2:40:37', '타타타다 (minoo0716):오예', '타타타다 (minoo0716)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:36:22'],
#  ['3:58:19', '아마맑음 (osd6808):몰가님?', '아마맑음 (osd6808)'],
#  ['3:45:14', '하와수 (chb8914):불ㅡㅡㅡ편', '하와수 (chb8914)'],
#  ['28:33', '킬리안음바페 (zlffldksdmaqkvp):무당준 ㄷㄷ', '킬리안음바페 (zlffldksdmaqkvp)'],
#  ['54:16', 'cgh310:갑분쉔', 'cgh310'],
#  ['3:50:49', 'kim941213:동 수 칸', 'kim941213'],
#  ['1:50:30', 'jsy9898:대-------------퍼', 'jsy9898'],
#  ['3:24:47', '푸시딘산나트륨 (lds1515):페이커 살아 있네', '푸시딘산나트륨 (lds1515)'],
#  ['3:49:17', 'blackcloud9:페이커 무빙 미친..', 'blackcloud9'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:04:56'],
#  ['3:35:24', '버닝 (qwsa302):아', '버닝 (qwsa302)'],
#  ['1:45:23', 'KOR1221:기가 막히다', 'KOR1221'],
#  ['4:05:04', '수감자45 (prisoner45):어유 저 밉상 자가', '수감자45 (prisoner45)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 4:05:25'],
#  ['54:31', '코크판다 (cokepandaa):대퍼 타임 ㅋㅋㅋㅋ', '코크판다 (cokepandaa)'],
#  ['3:40:35', '죄송해요손 (zxc996):킹갓구', '죄송해요손 (zxc996)'],
#  ['4:01:12', '쟈스민향기킁킁 (qchaeqchae):점멸 뭐하냐', '쟈스민향기킁킁 (qchaeqchae)'],
#  ['4:00:48', '욕은하지말죠 (nsjujje):트할머니 응디디 ㅋㅋㅋㅋㅋㅋ', '욕은하지말죠 (nsjujje)'],
#  ['3:26:15', '예솔이 (sdf045):혜지가 뭐여?!?', '예솔이 (sdf045)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:43:00'],
#  ['4:27:08', '기린아저씨 (gaejo9):문도', '기린아저씨 (gaejo9)'],
#  ['2:09:22', '부시밍 (boosiming):싱크안맞노', '부시밍 (boosiming)'],
#  ['4:29:29',
#   '급진적페미니스트김경현 (very_hot_fire_fist_gombo_):다데 ?ㅋㅋ',
#   '급진적페미니스트김경현 (very_hot_fire_fist_gombo_)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:23:28'],
#  ['3:59:08', '쿠르쿠르 (bluemoon287):ㅁㅁ', '쿠르쿠르 (bluemoon287)'],
#  ['3:23:22', '잼구나이트 (ejqmf92):skt 화이팅!!!!!!!!', '잼구나이트 (ejqmf92)'],
#  ['3:48:40', '루크로이 (jgj1807):잼구', '루크로이 (jgj1807)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:55:12'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:42:37'],
#  ['3:38:43', '수수옥 (ok971010):지나갑니다', '수수옥 (ok971010)'],
#  [' 게시 시간 33:43'],
#  ['13:35', '윤갑이 (jood3021):오늘 킹존한테 지면 skt 해체인가 ㄷㄷ', '윤갑이 (jood3021)'],
#  ['2:02:11', '윾두의권 (fist_of_nipple):왜냐! 윾도 미사일이라서!', '윾두의권 (fist_of_nipple)'],
#  ['4:32:05', '쿠리밍 (naong0126):컨트롤w누르면되여', '쿠리밍 (naong0126)'],
#  ['2:17:27',
#   '싹둑 (ssakdook):2018 LoL 챔피언스 코리아 섬머 : 6월 12일 ~ 7월 1일 / 7월 11일 ~ 8월 2일 / 8월 4일~ 8월 9일 ▣ 매주 월요일 휴무',
#   '싹둑 (ssakdook)'],
#  ['3:37:00', 'ksg107808:ㅁㅊ네', 'ksg107808'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:41:10'],
#  ['3:54:16', '게으름벵이 (rhkswkr7):운타라 왜 안나오징', '게으름벵이 (rhkswkr7)'],
#  ['45:33', '쿠르쿠르 (bluemoon287):쥬ㅡㅡ씨', '쿠르쿠르 (bluemoon287)'],
#  ['37:32', 'dolphin3266:14', 'dolphin3266'],
#  ['55:19', 'Wlgh2022:뽕뻐지냐!!', 'Wlgh2022'],
#  ['19:54', '이모카스주세요 (skh2938):케이티 전투력 측정기행 ㅋㅋㅋ', '이모카스주세요 (skh2938)'],
#  ['4:06:02', '오크니즘 (orcnizm):에포트 트할 탓이지. 퍼블 주고 탑에서 못 잡고', '오크니즘 (orcnizm)'],
#  ['57:15', '나는너가참좋다 (flgh):갓트록스님 은퇴경기 ㅠㅠ', '나는너가참좋다 (flgh)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:45:49'],
#  ['4:21:12',
#   'kdh4649yo:근데 트할도 트할이지만 봇 듀오가 발ㄹ려서 고릴라 발이 풀렼ㅅ다는게 펙트',
#   'kdh4649yo'],
#  ['1:11:37', 'JoYuneHo:쥬 씨 하 라', 'JoYuneHo'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 4:15:04'],
#  ['3:29:37', 'kyoda0607:닷지', 'kyoda0607'],
#  ['4:44:23', '한양양장점옆한영양장 (puorkme):ㅇㅇ 커즈 잘함', '한양양장점옆한영양장 (puorkme)'],
#  ['3:34:52', '다람쥐99 (gk0846):ㅁㅁ', '다람쥐99 (gk0846)'],
#  ['3:14:17', 'ehddnjs9081:우리게이 삼행시 할 줄 모르노', 'ehddnjs9081'],
#  ['1:50:20', '오잉칸 (scom804):동수칸', '오잉칸 (scom804)'],
#  ['4:08:55', '진세이파츠는호피팬티 (wjsiuy):가장의 무게..', '진세이파츠는호피팬티 (wjsiuy)'],
#  ['1:51:40', 'bini9636:용치고 있어서 떨어졌는데 그걸 싸우고 있네 밥통 kt', 'bini9636'],
#  ['3:47:57', 'redpanda1797:ㅁㅍ', 'redpanda1797'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:18:40'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:26:25'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 4:37:56'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:28:50'],
#  ['4:03:45', '섹시주안 (eclair731):재밌었따 ㅋㅋ', '섹시주안 (eclair731)'],
#  ['3:39:27', '도루코대검 (sjsmscksdn):음? 4서폿?', '도루코대검 (sjsmscksdn)'],
#  ['4:33:32', 'classes7:동 수 칸', 'classes7'],
#  ['4:42:43', '라플라스 (sagekyo):밀리는데?', '라플라스 (sagekyo)'],
#  ['4:23:33', 'wooking12:크트 그리핀 누가이김??', 'wooking12'],
#  ['20:13', '우리형이야왜그래 (nionhar):앙 초비다', '우리형이야왜그래 (nionhar)'],
#  ['1:51:13', '랑벨 (smillhm):쥬시... 으으악', '랑벨 (smillhm)'],
#  ['1:17:56', 'seegoale:노모 ㅋㅋㅋㅋㅋ', 'seegoale'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:46:51'],
#  ['1:39:59', '사랑은카레의노예 (tksclvlscl):금다이아 준위 있음', '사랑은카레의노예 (tksclvlscl)'],
#  ['3:29:32', '웃우 (misgnomer):호옹이 블리츠', '웃우 (misgnomer)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:57:08'],
#  ['46:56', '공기극딜 (spekdma):와 갈리오 아트록스 예술이네 진짜', '공기극딜 (spekdma)'],
#  ['4:09:38',
#   '수수수웁 (dlatnqlstpa1):ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#   '수수수웁 (dlatnqlstpa1)'],
#  ['4:39:53', '캬하하헬퍼아니야 (netnetll2):ㅈㅈ', '캬하하헬퍼아니야 (netnetll2)'],
#  ['55:54', 'ckc1545:도장깨기의 맛을 보았느냐?', 'ckc1545'],
#  ['3:18:29', 'bluing11:미드빵햇네', 'bluing11'],
#  ['1:57:57', '무루리 (alswns2893):장로 탈피', '무루리 (alswns2893)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:30:14'],
#  ['1:38:46', '마믹 (ma1mix):스코어를 만난것 자체로 타잔 디버프 ㅎㄷㄷ', '마믹 (ma1mix)'],
#  ['3:51:22', '공기극딜 (spekdma):뭐냐 게임 왤캐 싸우냐', '공기극딜 (spekdma)'],
#  ['3:53:03', '마비노오비 (qwas0579):자야 15렙이네 ㄷㄷ', '마비노오비 (qwas0579)'],
#  ['4:17:25',
#   'project00801:내가 1경기 때부터 싱크 지적했잖아. 귓등으로도 안듣더니 ㅉㅉㅉㅉㅉ',
#   'project00801'],
#  ['2:26:02', 'Chamring:또죽냐', 'Chamring'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:17:12'],
#  ['47:07', '이겜해보고싶어 (geeasdf):55도발 이 돌크리트놈들ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', '이겜해보고싶어 (geeasdf)'],
#  ['3:39:46', '야뿌야뿌 (esyzy96):리쉬 ㄳ', '야뿌야뿌 (esyzy96)'],
#  ['4:32:58', '테일러 (bp_tailor):오늘만큼은 갓 구다', '테일러 (bp_tailor)'],
#  ['4:14:53', '어쌔 (assassin5856):싱크 아까 게임때부터 안맞던데', '어쌔 (assassin5856)'],
#  ['54:29', 'gomseulgi210:?', 'gomseulgi210'],
#  ['4:40:32', 'somemore20:엉망이네 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', 'somemore20'],
#  ['3:17:54', 'haha168866:可和', 'haha168866'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 47:29'],
#  ['1:50:38', '봄사과 (refresh_mind):ㅋㅋㅋㅋㅋㅋㅋㅋㅋ 킅 아무고토 못하네', '봄사과 (refresh_mind)'],
#  ['', '54:48', '사상빨간_사춘기 (mx470):쥬씨하라', '사상빨간_사춘기 (mx470)'],
#  ['2:00:10', 'jing071776:ㅠㅠㅠ', 'jing071776'],
#  ['39:45', 'smile0420:아직까진 좋다', 'smile0420'],
#  ['3:26:15', '강윤님 (doompest1):오빠 나 뭐하몀ㄴ돼', '강윤님 (doompest1)'],
#  ['3:19:29', '덴젤커리 (kty4309):트할 팔뚝 ㄷㄷ', '덴젤커리 (kty4309)'],
#  ['2:14:20', '리따이준준 (dkwmqkffldna):2:0', '리따이준준 (dkwmqkffldna)'],
#  ['3:55:00', '말미 (hiu1012):ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', '말미 (hiu1012)'],
#  ['3:52:59',
#   'gabrielsukidayo:정글에 카카오,엄티가 있다면 서폿에는 에포트,울프가 있다 ㅇ ㅣㄱ ㅣㅇ ㅑ',
#   'gabrielsukidayo'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:40:10'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:15:00'],
#  ['4:36:46', '문어단대장 (applejamtoast):지독하다', '문어단대장 (applejamtoast)'],
#  ['2:18:33', '타타타다 (minoo0716):5위 6위 순위 바꿨뇨', '타타타다 (minoo0716)'],
#  ['3:43:26', 'ritzstar7:처형당할뻔 ㅋㅋㅋㅋ', 'ritzstar7'],
#  ['2:18:15', '포장용아이스팩 (raum_9114):ㅋㅋㅋㅋㅋㅋㅋㅋ케이티스럽게', '포장용아이스팩 (raum_9114)'],
#  ['1:26:03', '대디 (yi1214):그리핀 질듯', '대디 (yi1214)'],
#  ['1:51:02', '포코라 (pokora3823):혐도 ㅋㅋㅋ', '포코라 (pokora3823)'],
#  ['3:21:50', 'hochani:ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', 'hochani'],
#  ['1:53:35', '섹순신 (story7676):문도 너프좀', '섹순신 (story7676)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:12:21'],
#  ['3:21:44', 'dkffkels482:100한 이미지', 'dkffkels482'],
#  ['48:14', '남천동 (smartboy1203):마타님?', '남천동 (smartboy1203)'],
#  ['20:36', '다데 (dadeshogun):그리핀 실질적 코치가 도파임', '다데 (dadeshogun)'],
#  ['4:00:14', '밥보다빵 (wkdrh92):진짜 트할', '밥보다빵 (wkdrh92)'],
#  ['4:08:32', '게으른혹등고래 (jinsihu):연기력늘었어진짴ㅋㅋㅋㅋㅋㅋㅋㅋㅋ', '게으른혹등고래 (jinsihu)'],
#  ['1:00:04', '보호주의구멍 (trtjbull6007):?', '보호주의구멍 (trtjbull6007)'],
#  ['3:56:33', '민딘이 (dlrcoel):딜이 안될건데', '민딘이 (dlrcoel)'],
#  ['1:49:04', '고양이가좋다 (glfhtkakd):개쌔네', '고양이가좋다 (glfhtkakd)'],
#  ['3:44:37', 'roar8888:고릴라 잘땡기네', 'roar8888'],
#  ['3:49:26', 'rksid:신 갓 혁', 'rksid'],
#  ['4:16:04', 'hztimothy:저거 한대 더 때렸으면 경기 아예 달라졌다', 'hztimothy'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:06:51'],
#  ['33:22', '저급어그로 (ekekr):오우야;', '저급어그로 (ekekr)'],
#  ['2:00:19', 'hygjh5:1퍼센트의 기적', 'hygjh5'],
#  ['4:03:33', 'dhgml0212:소라카는 왜 했냐진짜', 'dhgml0212'],
#  ['4:33:43', '밋너 (kjihong9):나라 잃은 김구다', '밋너 (kjihong9)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 4:19:58'],
#  ['3:54:42', 'Spvls0613:와 페이커 ;;', 'Spvls0613'],
#  ['3:55:07', '0레옹0 (kar5000):어머니,,,', '0레옹0 (kar5000)'],
#  ['4:40:17', '엘토네이도 (fpsava):?', '엘토네이도 (fpsava)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:17:05'],
#  ['1:32:11', 'qpemfh11:킹갓코어 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 국대정글러 ㅋㅋㅋㅋㅋㅋ', 'qpemfh11'],
#  [' 게시 시간 30:50'],
#  ['37:01', 'ajden3:강타의신', 'ajden3'],
#  ['3:40:33', 'Lalamut:이걸 맞추네, 평소 블랭크가 아니네', 'Lalamut'],
#  ['4:41:59', '딱코딱뎀딱카드 (potsurehi):페 석 머', '딱코딱뎀딱카드 (potsurehi)'],
#  ['27:39', '욱종이 (wookjong2):정글노잼이네', '욱종이 (wookjong2)'],
#  ['3:57:05', '하늘의또다른태양조강현 (parkga1342):간장게장 ㅋㅋㅋㅋ', '하늘의또다른태양조강현 (parkga1342)'],
#  ['2:08:50', '오나미오나홀 (yooyoungbin):문도 개무시가 답인가', '오나미오나홀 (yooyoungbin)'],
#  ['4:36:23', 'kungs_kungs_kungs:적', 'kungs_kungs_kungs'],
#  ['1:01:58', '나는정환 (hahadin):진짜 아무말이나 막하네', '나는정환 (hahadin)'],
#  ['2:55:09', '06_02_04:멈춤', '06_02_04'],
#  ['1:15:23', 'buffadpls231:그리핀은 트릭이다', 'buffadpls231'],
#  ['3:52:53', '버질반씨반다익 (jh5902):페이커 보이지 않는 1데스 있나', '버질반씨반다익 (jh5902)'],
#  ['1:09:45', '동티모르꽃거지 (dzt2):유사말파이트', '동티모르꽃거지 (dzt2)'],
#  ['3:52:30', '갈라파고엔시스 (wgp2000):역시 히오스를 해야....', '갈라파고엔시스 (wgp2000)'],
#  [' 게시 시간 18:04'],
#  ['2:05:02', 'kimbbongs:케넨 엠비피', 'kimbbongs'],
#  ['1:02:17', 'lis0920:장어 ㄷㄷㄷㄷ', 'lis0920'],
#  ['1:59:24',
#   '나오토모리 (dudndltkdgus):ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#   '나오토모리 (dudndltkdgus)'],
#  ['2:08:03', '렐다 (relda1):쥬시하라...', '렐다 (relda1)'],
#  ['3:09:40', 'gjays96:용준할까 단군할까 ㅋㅋㅋ', 'gjays96'],
#  ['1:37:37', 'nhg9696:갓 그리핀', 'nhg9696'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:21:06'],
#  ['4:40:22', 'h_e_y_guy:뱅ㅋㅋ', 'h_e_y_guy'],
#  ['2:29:35', '캐종 (gold1022):ㄷㄷㄷㄷㄷ', '캐종 (gold1022)'],
#  ['3:30:26', '신이둥이 (siny_c):혼란하다 혼란해', '신이둥이 (siny_c)'],
#  ['39:37', 'jjla95:멀티테스킹 미쳤네', 'jjla95'],
#  ['53:13', '힐러조 (wngh1423):함정 과학 ㄷㄷ', '힐러조 (wngh1423)'],
#  ['2:04:40', '주니황 (lkklklk):담당일진ㅋㅋㅋㅋㅋ', '주니황 (lkklklk)'],
#  ['4:23:43', '한입만 (gur777):에포트 탐켄치네 졌다', '한입만 (gur777)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:03:49'],
#  ['4:33:40', '천칭별 (pjh71042002):ㅋㅋㅋㅋㅋㅋㅋㅋ', '천칭별 (pjh71042002)'],
#  ['4:36:50', '쪼카리 (hjjang1000):또간다ㅋㅋㅋㅋㅋㅋㅋㅋ', '쪼카리 (hjjang1000)'],
#  ['2:59:11', 'moncher00:우천 때문에 시간 멈췄다네여', 'moncher00'],
#  [' 게시 시간 16:29'],
#  ['4:34:50', '한잔할래 (gnsdudak):전자개돌??', '한잔할래 (gnsdudak)'],
#  ['1:33:45', 'userdew:ㅁㅍ', 'userdew'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 4:40:16'],
#  ['1:33:49', 'h_e_y_guy:ㅁㅍ', 'h_e_y_guy'],
#  ['3:51:37', '맘스터치햄버거 (podong0990):와', '맘스터치햄버거 (podong0990)'],
#  ['4:33:43', '피조아 (whaql666):동 수 칸', '피조아 (whaql666)'],
#  ['1:41:22', 'dovoodoo1:바이퍼 케넨 끌어오고 케넨 궁터짐 ㅋㅋㅋㅋㅋㅋㅋㅋ', 'dovoodoo1'],
#  ['20:58', '끌끌 (chydna):쵸비말고 다른 미드라이너는 누구임?', '끌끌 (chydna)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 4:14:43'],
#  ['3:41:17', '루트루트루트 (qudrms2718):그리핀 떡발림', '루트루트루트 (qudrms2718)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:34:42'],
#  ['3:23:20', '브리슬 (qwdf29):갈라쇼', '브리슬 (qwdf29)'],
#  ['3:59:21', 'Coed3456:빛 혜 지', 'Coed3456'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 4:10:35'],
#  ['1:44:16', '토니웩 (tonywack1703):응 215', '토니웩 (tonywack1703)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:46:04'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:21:13'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:05:16'],
#  ['4:33:00', 'seonggon9494:동 수 칸', 'seonggon9494'],
#  ['1:30:25', '검은건반 (junheon):오우예', '검은건반 (junheon)'],
#  ['1:32:43', '어디로든지 (rrg985):?', '어디로든지 (rrg985)'],
#  ['3:17:40', '서울은1시30분 (my562):커즈 ㄷㄷ', '서울은1시30분 (my562)'],
#  ['2:03:31', 'rokpd2007:케넨스맵못씀', 'rokpd2007'],
#  ['1:45:06', '아나마타 (kcv4022):이건 대퍼다', '아나마타 (kcv4022)'],
#  ['1:09:40', '엑스펙스 (bydream11):쥬시하라', '엑스펙스 (bydream11)'],
#  ['57:09', 'cubix111:그리핀 1.5 존끄들 했네', 'cubix111'],
#  ['1:05:25', '리플리조커 (narajjang75):뭔가 마지막 롤챔스 같구먼..', '리플리조커 (narajjang75)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:45:36'],
#  ['4:08:30', '잭스밖에난몰라 (rlaxogjs92):.............', '잭스밖에난몰라 (rlaxogjs92)'],
#  ['4:38:14', 'patmanbullet:oo', 'patmanbullet'],
#  ['1:01:36', '딩동빌런 (ojh147):1세트 누가 이김?', '딩동빌런 (ojh147)'],
#  ['3:49:05', 'MeMyselfAndIGG:상혁이 너무한데', 'MeMyselfAndIGG'],
#  ['2:28:27', '불낙전골허재 (sorh78):샤잭스보고와라', '불낙전골허재 (sorh78)'],
#  ['50:45',
#   '급진적페미니스트김경현 (very_hot_fire_fist_gombo_):대ㅡㅡㅡㅡ퍼',
#   '급진적페미니스트김경현 (very_hot_fire_fist_gombo_)'],
#  ['2:04:28', '최강기아타이거즈 (qwe7363):아트럭스.너무 쌔다 ㄹㅇ', '최강기아타이거즈 (qwe7363)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 40:34'],
#  ['41:37', 'wasd002:KT가 담당 일진 되는거냐 ㄷㄷ', 'wasd002'],
#  ['3:46:02', '흔한미일한국인 (grantmoon96):킹 릴 라', '흔한미일한국인 (grantmoon96)'],
#  ['2:18:33', '배린배린배린이 (kong8986):ㅋㅋㅋ 진짜 개판인데?', '배린배린배린이 (kong8986)'],
#  ['4:39:34', '몽쉴통통 (hahaha345):ㅋㅋ', '몽쉴통통 (hahaha345)'],
#  ['3:30:09',
#   '노폐인노게임 (letmiraclesky):???????????????????',
#   '노폐인노게임 (letmiraclesky)'],
#  ['23:06', 'hmhee07:코돈빈!!!!!', 'hmhee07'],
#  ['47:16', 'guswns4087:아트록스 너프 시원하게 잘먹었다 ㄹㅇ', 'guswns4087'],
#  ['46:03', '리플리조커 (narajjang75):꼬오오오오오ㅜ???', '리플리조커 (narajjang75)'],
#  [' 게시 시간 17:14'],
#  ['1:45:25', '구까이 (hankkang24):대퍼는 과학 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', '구까이 (hankkang24)'],
#  ['4:40:31', '클템개잘함 (jic2438):에포트 뭐해', '클템개잘함 (jic2438)'],
#  ['4:09:54', 'zjsxmfhf0:띵작', 'zjsxmfhf0'],
#  ['48:14', 'sang99246:원딜출현', 'sang99246'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:01:42'],
#  ['3:49:02', '블랙베리 (rawkasa):이걸 트할이?', '블랙베리 (rawkasa)'],
#  ['4:05:22', '루크로이 (jgj1807):ㅋㅋㅋㅋ딜량 ㅋㅋㅋㅋㅋ', '루크로이 (jgj1807)'],
#  ['4:32:56', '드루야캐요 (heyapples21):갓구', '드루야캐요 (heyapples21)'],
#  ['4:02:41', '매드야인 (sky3415):저 스킨이 피하기 넘 힘듬', '매드야인 (sky3415)'],
#  ['1:41:50', '다시다마시다 (dismalian):가차없죠', '다시다마시다 (dismalian)'],
#  ['1:11:58',
#   '웁곰 (ooooooooooooooooooooopgm):와 쓸어담는다',
#   '웁곰 (ooooooooooooooooooooopgm)'],
#  ['55:08', '술꾼 (hcw698):대퍼', '술꾼 (hcw698)'],
#  ['1:57:27', '누가물어봄 (factattacking):아니저거뭐냐고 ㅋㅋ', '누가물어봄 (factattacking)'],
#  ['3:23:58', '조라땅다이스키 (younghwan33):팬덤이 커서 꼴팬도 많지', '조라땅다이스키 (younghwan33)'],
#  ['4:00:23', 'tenber1000:ㅁㅁ', 'tenber1000'],
#  ['50:12', '동티모르꽃거지 (dzt2):신입생 담당일찐 ㄷ', '동티모르꽃거지 (dzt2)'],
#  ['1:16:18', '멋진소나무 (skan3697):브라움밴해', '멋진소나무 (skan3697)'],
#  ['4:09:53', '에키홀릭 (leejh0901):오지엔 약빨았나 ㅋㅋㅋㅋ', '에키홀릭 (leejh0901)'],
#  ['1:57:20', '공성과피자 (tdazzlili):소드마스터ㅓㅓㅓㅓㅓㅓㅓㅓㅓㅓㅓㅓㅓㅓ', '공성과피자 (tdazzlili)'],
#  ['39:15', '나는정환 (hahadin):용컨트롤 구리네', '나는정환 (hahadin)'],
#  ['2:01:52',
#   '가나다라마바사아자차카마 (txt1112):짱트록스님 그립습니다 ㅠㅠ',
#   '가나다라마바사아자차카마 (txt1112)'],
#  ['33:39', 'Maaagic11:뿔꽃의..', 'Maaagic11'],
#  ['3:49:31', 'koiewq123:페이커합류 너무늦었네', 'koiewq123'],
#  ['49:50', '하와수 (chb8914):케이지', '하와수 (chb8914)'],
#  [' 게시 시간 13:19'],
#  ['3:43:24', '날아라곰탱이 (fbwjdgns05):잼구할뻔', '날아라곰탱이 (fbwjdgns05)'],
#  ['3:30:07',
#   '에이씨55 (sungwoo5957):뱅한태 모르거나 시키더니 이번엔 소라카냐',
#   '에이씨55 (sungwoo5957)'],
#  ['2:16:53', 'cleasky7:국 대 정 글', 'cleasky7'],
#  ['1:53:37',
#   '챱챱넘좋아 (rabid527):넌해고 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#   '챱챱넘좋아 (rabid527)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:59:15'],
#  ['3:56:37', '츄랄 (shapeofm):ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', '츄랄 (shapeofm)'],
#  ['1:50:29', 'audcks94:대ㅡ퍼', 'audcks94'],
#  ['4:37:43', '똘강 (fpel01):근데 슼은 초반 좋으면 개불안함', '똘강 (fpel01)'],
#  ['4:00:15', '크라이2 (ghyenkim):트할 개똥싸네', '크라이2 (ghyenkim)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 4:03:46'],
#  ['1:57:33', '멍청아메룡 (ambbadda):ㅋㅋㅋㅋ 동수칸 팀운 안좋은거봐 ㅋㅋㅋ', '멍청아메룡 (ambbadda)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 4:11:26'],
#  ['3:34:55', '대장나아무 (khm9907):저게 끌리네', '대장나아무 (khm9907)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:05:57'],
#  ['1:45:15', '끈끈 (rmsqja94):대퍼타임', '끈끈 (rmsqja94)'],
#  ['4:04:41', 'oarseller1:운블페벵울 나와라', 'oarseller1'],
#  ['3:51:52', '똘망똘망 (kimgang1102):핵 꿀잼', '똘망똘망 (kimgang1102)'],
#  ['3:57:17', '우유에빠진냥이 (dkue3):뭔가 이상한 이득 ㅋㅋㅋㅋㅋㅋㅋ', '우유에빠진냥이 (dkue3)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:38:59'],
#  ['3:28:00', '류설혜 (jjh42566):페이커 특) 블라디하면 짐', '류설혜 (jjh42566)'],
#  [' 게시 시간 17:45'],
#  ['3:30:33', 'jang2031:아 트롤픽 ㅋㅋㅋㅋㅋㅋㅋ', 'jang2031'],
#  ['4:08:58', 'whitemoon789:구와아아아악... 아이엠그루트;;', 'whitemoon789'],
#  ['4:40:30', '류드밀라 (601cool713):크', '류드밀라 (601cool713)'],
#  [' 게시 시간 17:05'],
#  ['4:13:08', '우유에빠진냥이 (dkue3):칸 목 ㄷㄷ', '우유에빠진냥이 (dkue3)'],
#  ['1:52:01', 'Geryos12:비전 투시', 'Geryos12'],
#  ['2:05:04', '똥덱장인따혀니 (samuelas215):K2:G0ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', '똥덱장인따혀니 (samuelas215)'],
#  ['1:58:57', '업사 (yp071605):슈-퍼팀이었다', '업사 (yp071605)'],
#  ['3:37:56', '똘망똘망 (kimgang1102):저거왜삼? 평타거리안담?????', '똘망똘망 (kimgang1102)'],
#  ['1:10:12', 'hoonisa:갈아버려', 'hoonisa'],
#  ['3:50:59', '뭐되더놈 (illegalp1):ㅋㅋㅋㅋㅋㅋ', '뭐되더놈 (illegalp1)'],
#  ['2:04:14', 'kokcal:크', 'kokcal'],
#  ['1:45:26', '집관리인 (woong1519):대ㅡㅡㅡㅡㅡㅡ퍼', '집관리인 (woong1519)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:38:22'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 59:40'],
#  ['4:03:37', '느허으악 (ghdwls999):싫어 ㅋㅋㅋㅋ', '느허으악 (ghdwls999)'],
#  ['2:03:46', '포코라 (pokora3823):대-퍼 올뻔 ㅋㅋ', '포코라 (pokora3823)'],
#  ['4:38:30', '환상 (toytanicc):칸이 얼마나 망했냐면 정글보다 렙 낮음 ㅋㅋㅋ', '환상 (toytanicc)'],
#  ['3:49:21', '으아아아앆 (dwanjjang):않이 라칸 정글 뭐임?ㅋㅋㅋㅋ', '으아아아앆 (dwanjjang)'],
#  ['3:47:25',
#   '왁희 (khm99629):슼팬들은 항상 탓하기 바쁘네 서폿차이가 아니라 그냥 팀차이다',
#   '왁희 (khm99629)'],
#  ['3:46:12', '건우디 (mtwelvebk):이게왜 잼구냐ㅋㅋㅋㅋ', '건우디 (mtwelvebk)'],
#  ['1:06:00', 'kolk23:갓경누나....그립읍니다....', 'kolk23'],
#  ['58:34', '스졸렬 (mlli1412):모데 w 비빈거도 크다', '스졸렬 (mlli1412)'],
#  ['1:09:16', '힐러조 (wngh1423):삼각혀 ㅗㅜㅑ', '힐러조 (wngh1423)'],
#  ['2:07:54', '베개랑나랑 (ranafl):스맵 뒷텔이 하이라이트지', '베개랑나랑 (ranafl)'],
#  ['4:46:46', 'did_gombo_enlist_yet:문도 사기는 맞아 롤알못아', 'did_gombo_enlist_yet'],
#  ['4:42:51', '달패앵이 (marine732k):트할 킬먹고 하는거 없음', '달패앵이 (marine732k)'],
#  ['1:50:44', '나무깍는노인 (dkzlakfn):진짜 용준이과학이야', '나무깍는노인 (dkzlakfn)'],
#  ['4:34:28', 'kuramati:ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', 'kuramati'],
#  ['30:13', '텐서스 (gyeongbin):어깨 싸움봐 ㅋㅋㅋㅋㅋㅋ', '텐서스 (gyeongbin)'],
#  ['2:16:47', '오다주웠다 (kasibo7):zzzzzzzzzz', '오다주웠다 (kasibo7)'],
#  ['2:26:19', 'wkdudrhkd:그악타 ㅋㅋㅋㅋㅋ', 'wkdudrhkd'],
#  ['1:45:12', 'kaloce1:스맵이 제대로 던졌다', 'kaloce1'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:30:24'],
#  ['2:10:11', 'Alche96:ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', 'Alche96'],
#  ['', '3:45:17', '믛흠믛흠믛 (eogks9090):봇이 밀리는게 좀 크네', '믛흠믛흠믛 (eogks9090)'],
#  ['4:08:01', 'rkaak33:2경기땐 선수 바꾸자', 'rkaak33'],
#  ['3:33:44',
#   '겉은바삭속은촉촉한조팡현 (garrosh_hellsteelo):투미드 ㄷㄷㄷㄷ',
#   '겉은바삭속은촉촉한조팡현 (garrosh_hellsteelo)'],
#  ['53:29', 'zkze357:그리핀 밴픽 뭐 자따구로함?;;', 'zkze357'],
#  ['4:32:53', '흐에호야홋 (tjdwnszxcv):오늘 갓구 잘하네', '흐에호야홋 (tjdwnszxcv)'],
#  ['3:32:09', '메론파 (wkfmwnd):혜지 모름???', '메론파 (wkfmwnd)'],
#  ['4:31:22', '혀낙이 (jar5382):6승1패임', '혀낙이 (jar5382)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:30:04'],
#  ['3:59:07', '쓰팀 (khj921227):플ㅋㅋㅋㅋㅋㅋㅋㅋ', '쓰팀 (khj921227)'],
#  ['4:20:12', 'Npn1934:트할 : 던짐 ㅅㄱ', 'Npn1934'],
#  ['1:45:06', 'ㅁㄴ (rno159):대퍼', 'ㅁㄴ (rno159)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:54:06'],
#  ['4:14:25',
#   '나는꿈에서나비였소 (someaugust17):빛돌.. 제발 안나왔으면....',
#   '나는꿈에서나비였소 (someaugust17)'],
#  ['2:10:21', 'dkrnwl11:춘봉바크', 'dkrnwl11'],
#  ['1:31:39', '아삼작클라크 (bibo502):ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', '아삼작클라크 (bibo502)'],
#  ['1:52:40', '트위치마니보는사람 (twitchjoaing):평범한 대퍼자나?', '트위치마니보는사람 (twitchjoaing)'],
#  ['4:04:51', 'aowldps:ㄱㅁ', 'aowldps'],
#  ['1:45:21', '피마원 (ljhzzang1530):용-준', '피마원 (ljhzzang1530)'],
#  ['4:07:58', 'yuredong:1+1ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', 'yuredong'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 4:24:32'],
#  ['4:39:33', '향시 (ashwhite):ㅋㅋㅋㅋㅋㅋ', '향시 (ashwhite)'],
#  [' 게시 시간 8:24'],
#  ['1:45:50', '백수왕한백수 (vpcea25fk):타잔 개잘하네진짜', '백수왕한백수 (vpcea25fk)'],
#  ['54:11', 'everlong09:ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', 'everlong09'],
#  ['1:31:25', '채팅창무게감오지죠 (uh6400):와', '채팅창무게감오지죠 (uh6400)'],
#  ['1:32:38', 'Sococt54312:?', 'Sococt54312'],
#  ['4:08:41', '남산코렁탕 (ydmg0):클하다 추템아', '남산코렁탕 (ydmg0)'],
#  ['1:50:30', '양을쫓는아이 (wonterkid):ㅋㅋㅋㅋㅋㅋㅋㅋ', '양을쫓는아이 (wonterkid)'],
#  ['3:54:42', '희섭 (khsdfg952):우리혁이맞습니다', '희섭 (khsdfg952)'],
#  ['1:37:39', 'irnalf:대퍼 ㅇ오반데', 'irnalf'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:32:51'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 49:07'],
#  ['4:43:04', '크롱크룽크롱 (tavasz114):뱅 너무못했어 스웨인', '크롱크룽크롱 (tavasz114)'],
#  ['3:55:12',
#   '휘파람파람파람파람 (britzrush):와 근데 오늘 꿀잼이네 ㅋㅋㅋㅋㅋㅋㅋ',
#   '휘파람파람파람파람 (britzrush)'],
#  ['18:53', '평범한하늘 (blueskyer00):그리핀 세트포함해서 2패밖에 안했네..', '평범한하늘 (blueskyer00)'],
#  ['33:39', '싼타 (dnqjqud):폭격기', '싼타 (dnqjqud)'],
#  ['2:12:53', 'iuiurm:크 유신병 답변이 모범적이야', 'iuiurm'],
#  ['3:11:22', 'ykjk1401:히오스', 'ykjk1401'],
#  ['4:02:23', '몬짐 (monstergym):아주 블리츠오니깐 아무고토모타쥬', '몬짐 (monstergym)'],
#  ['1:45:06', '쿨파 (bsh2313):춘봉씨 대퍼', '쿨파 (bsh2313)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 47:58'],
#  ['3:44:34', '홀생 (tlsdltls):잼구똥꾸', '홀생 (tlsdltls)'],
#  ['1:26:54', 'mike6636:슼그리핀한테 이미한번 짐', 'mike6636'],
#  ['1:07:32', '좌동준 (leftdongjun):갓살표 ㄷㄷ', '좌동준 (leftdongjun)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:22:56'],
#  ['4:04:54', '피오옝 (wogur2545):미드차이인듯 ㅋㅋ', '피오옝 (wogur2545)'],
#  ['3:58:22', '쉴라이트 (powjddlr):??', '쉴라이트 (powjddlr)'],
#  ['4:18:41', 'gkdmdrk:ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', 'gkdmdrk'],
#  ['2:07:57', 'zoqxlsgh:딜보소 킹트록스', 'zoqxlsgh'],
#  ['3:28:20', 'ms20485039:kt', 'ms20485039'],
#  ['1:41:15', '싼타 (dnqjqud):폭격기가 불까지 끄네', '싼타 (dnqjqud)'],
#  [' 게시 시간 6:13'],
#  ['1:08:07', 'splloover:갓콩', 'splloover'],
#  ['3:46:08', '쌈바쌈바 (gkwk70):잼구는 못말ㄹ', '쌈바쌈바 (gkwk70)'],
#  ['1:12:18', '2월의귀인 (yorsion):쥬씨하라아', '2월의귀인 (yorsion)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 4:28:01'],
#  ['', '4:03:45', '멋진소나무 (skan3697):진짜 고ㅜ릴라 미쳣다', '멋진소나무 (skan3697)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:45:45'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:08:55'],
#  ['4:18:26', 'cocopalm22:아프리카 가야지 싱크안맞아서 못보겠따', 'cocopalm22'],
#  ['2:05:46', 'wjdtn1013:스맵킹넨이지렷음', 'wjdtn1013'],
#  ['4:26:42', '탑정글만갈게요 (cdy2732):블라디를해 제발 트할형', '탑정글만갈게요 (cdy2732)'],
#  ['29:57', '침대인간 (applier):노딜조합 ㅋㅋ', '침대인간 (applier)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 52:14'],
#  ['4:04:21', 'sa2daman:금수의 왕', 'sa2daman'],
#  ['1:43:05', 'Legendrend:??????', 'Legendrend'],
#  ['3:09:23', '무지개색미라클 (korsolar):ㅇ', '무지개색미라클 (korsolar)'],
#  ['3:36:41', 'givemetip:ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', 'givemetip'],
#  [' 게시 시간 12:24'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:28:29'],
#  ['4:21:59', '로맨스토커 (kmoh7737):스카너 갈리오 조합 나올듯', '로맨스토커 (kmoh7737)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:07:10'],
#  ['2:41:58', '15살푸틴피푸틴 (du9172):싹뚝이 아다 짤림 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', '15살푸틴피푸틴 (du9172)'],
#  ['', '4:44:46', '카레다음깍두기 (curry5939):짜오 유통기한와서 망함', '카레다음깍두기 (curry5939)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 4:22:43'],
#  ['3:22:33', '포스트지 (park1713):페이커..', '포스트지 (park1713)'],
#  ['2:02:32', 'kamatasong:그리핀 거품 다 빠지네', 'kamatasong'],
#  ['4:25:52', '최종학력피자스쿨 (olll):그브각', '최종학력피자스쿨 (olll)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:03:33'],
#  ['1:36:35', '박용 (pakyong):물럿거라!', '박용 (pakyong)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:30:09'],
#  ['3:30:14', 'gourmetnut:리폿 ㅅㄱ', 'gourmetnut'],
#  ['3:54:27', '마베이스 (madrumm):와 빠커 ㅋㅋㅋㅋ', '마베이스 (madrumm)'],
#  ['2:07:10', 'zecrastar:ㄹㅇ', 'zecrastar'],
#  [' 게시 시간 3:03'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:47:46'],
#  ['1:45:07', '허미트29 (dbsdydgml20):그리핀의 한타', '허미트29 (dbsdydgml20)'],
#  ['1:45:44', '난방고냥이 (neutonic8915):스매부가 이걸 ㅋㅋㅋ', '난방고냥이 (neutonic8915)'],
#  ['1:51:53', '로스카흑우 (march1157):전투를 하지 않을 시', '로스카흑우 (march1157)'],
#  ['1:50:15', 'Uang0622:야 근데 문도가 안죽어 ㅋㅋㅋㅋㅋㅋㅋㅋ', 'Uang0622'],
#  ['4:03:25', '하이어1 (higherplace1):aa', '하이어1 (higherplace1)'],
#  ['2:04:53', '낭낭쭙쭙 (xellew147):신입생 이기고 너모 좋아한다 ㅋㅋㅋㅋㅋㅋㅋ', '낭낭쭙쭙 (xellew147)'],
#  [' 게시 시간 8:05'],
#  ['58:15', '자칼54 (na6game):딜 안박히는거보소 야스오', '자칼54 (na6game)'],
#  ['1:16:10', 'mudohaha:춘봉박 1세트 날라다님', 'mudohaha'],
#  ['1:52:03', '계략 (gyeryak):Vision 투시', '계략 (gyeryak)'],
#  ['1:29:11', 'dwadwwq:ap케넨이네', 'dwadwwq'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:41:27'],
#  ['4:22:48', '그이유르흐을 (aldksgodld):왤케 흐릿함 해상도꺠지는거봐', '그이유르흐을 (aldksgodld)'],
#  ['46:54', '토토로기여워 (totoro0216):와 도발각도 스킬각도 예술..', '토토로기여워 (totoro0216)'],
#  ['', '4:29:36', '박무지 (powernanana):뱅기 아련...', '박무지 (powernanana)'],
#  ['4:40:16', '흑안개 (sans8462):정글냠냠', '흑안개 (sans8462)'],
#  ['4:40:28', '리야제 (tom880726):둥글게 둥글게', '리야제 (tom880726)'],
#  ['41:47', 'explorer8595:KT가 뜬금없이 이런애들 잡더라', 'explorer8595'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:34:07'],
#  ['3:39:44', '쿠우닥터 (cruelbait):ㅋㅋㅋ이걸 먹네', '쿠우닥터 (cruelbait)'],
#  ['1:10:52', '로봇 (aiuansd):안녕', '로봇 (aiuansd)'],
#  ['42:57', '씨리얼다내꺼 (d2245no1):와 진짜 해설차이오진다', '씨리얼다내꺼 (d2245no1)'],
#  ['42:43', '요들법사 (kbh1420):전승 담당 일찐 ㅋㅋ 쉔 짜른게 진짜 좋은 밴픽이였다', '요들법사 (kbh1420)'],
#  ['2:01:06', '따워 (rktower010):발싸!!!!!', '따워 (rktower010)'],
#  ['32:08', 'lensio16:비비큐 롤드컵 우승스킨;', 'lensio16'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 58:14'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:16:08'],
#  ['2:09:52', 'qqqq784512:??????????', 'qqqq784512'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 47:11'],
#  ['3:30:44', '팬티색이머냐 (kiker0):머여', '팬티색이머냐 (kiker0)'],
#  ['3:49:53', 'eogkrdnjs:소라카 궁이', 'eogkrdnjs'],
#  ['4:33:26', '초련행 (noctiluca001):한입만 ㅜㅜ', '초련행 (noctiluca001)'],
#  ['3:57:02', 'hhchong:ㅁㅍ', 'hhchong'],
#  ['4:33:54', 'zephyk7:나라 잃었다 동수칸', 'zephyk7'],
#  ['4:36:17', '차냥한다 (t53171213):줄건줘', '차냥한다 (t53171213)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 4:23:31'],
#  ['4:01:41', '우리번 (smrmqjs):저걸 그럼 안오냐 븅들 결과론지리네', '우리번 (smrmqjs)'],
#  ['1:37:28', '풍멍댕이 (wish824):대 퍼 타 임', '풍멍댕이 (wish824)'],
#  ['1:53:34', '끄로마뇽 (simin0316):넌 해고얔ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', '끄로마뇽 (simin0316)'],
#  ['1:58:24',
#   '평범한정원사 (pak113665):ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#   '평범한정원사 (pak113665)'],
#  ['1:40:57', 'mummoomy:춘넨 ㄷㄷㄷ', 'mummoomy'],
#  ['4:06:07', 'abcd0654:페이커 넋나간거보소', 'abcd0654'],
#  ['14:40', '돼지강신우 (ksw3214):스포티비가 누나들볼수잏어서 좋은데 ㅠㅠ', '돼지강신우 (ksw3214)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 49:14'],
#  ['4:33:01', '빅2 (asda725):야구나이트', '빅2 (asda725)'],
#  ['3:54:24', '해아니 (dlfghldyd4684):?', '해아니 (dlfghldyd4684)'],
#  ['1:51:10', '차레이 (asheka):혐도 풀피 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ', '차레이 (asheka)'],
#  ['3:31:02', 'tkddyddl:ㄹㅇ 혼돈', 'tkddyddl'],
#  ['3:27:59', '씹덕혐오자 (dltlgud8426):페이커 카시 가즈아ㅏㅏㅏㅏㅏㅏㅏ', '씹덕혐오자 (dltlgud8426)'],
#  ['1:41:04', '얼어붙은왕국의룩공얍 (carta987):와 신맵ㅋㅋㅋㅋㅋ', '얼어붙은왕국의룩공얍 (carta987)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:35:43'],
#  ['56:17',
#   '웁곰 (ooooooooooooooooooooopgm):매치 패배하나?',
#   '웁곰 (ooooooooooooooooooooopgm)'],
#  ['40:47', 'Zhfspt:리멕 아트록스 꾸지긴 꾸졌더라', 'Zhfspt'],
#  ['57:59', 'flamewarhammer:Juicy하라~', 'flamewarhammer'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:15:48'],
#  ['3:12:47', 'deuxmj123:SKT이기즈아', 'deuxmj123'],
#  ['3:35:30', '몬짐 (monstergym):소리싱크왜이래', '몬짐 (monstergym)'],
#  ['53:26', '보노씨 (cdragon777):야스오이즈 사이언스', '보노씨 (cdragon777)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:30:11'],
#  ['1:37:31', '킬리안음바페 (zlffldksdmaqkvp):춘봉박 ㄷㄷ', '킬리안음바페 (zlffldksdmaqkvp)'],
#  ['1:56:43', '나성호임 (tjdgh9629):문도 와애댈텐데', '나성호임 (tjdgh9629)'],
#  ['1:54:12', '응기잇삼봉이 (tlfwkdtjr):쫄', '응기잇삼봉이 (tlfwkdtjr)'],
#  ['3:19:01', '정힙오 (ghdiwltkd):이제 울프는 ...', '정힙오 (ghdiwltkd)'],
#  ['1:29:40', '열2 (duf21122):비원딜 원딜이 뭐냐...', '열2 (duf21122)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:30:12'],
#  ['3:54:52', 'shin1120:소라카 ㄷㄷ', 'shin1120'],
#  ['1:09:22', '아두이노 (randruner):55도발 ㄷㄷ', '아두이노 (randruner)'],
#  ['1:08:35', '띠띵띠띵띠 (insengiran):빛돌쟝 오늘도 셔츠 못다렸네', '띠띵띠띵띠 (insengiran)'],
#  ['1:42:22', 'sindc37:그리핀 진짜 거품이었나?', 'sindc37'],
#  ['4:03:56', '애증 (lachesis105):커즈 라칸 왜케잘하냐 ㅋㅋㅋㅋㅋㅋㅋㅋ', '애증 (lachesis105)'],
#  ['1:31:29', '윾두의권 (fist_of_nipple):야 대 한 코 글 러', '윾두의권 (fist_of_nipple)'],
#  ['3:37:12', '앵준이 (hyunjunnk):ㅡ할 진짜 ㅡㅡ', '앵준이 (hyunjunnk)'],
#  ['44:38', '로파파_유칼 (skasa37):KT=Korean Team ㄷㄷ', '로파파_유칼 (skasa37)'],
#  ['3:37:14', 'Hasiri88:아니 트할 머해', 'Hasiri88'],
#  ['2:10:34', '아리까ㄹㅣ (apfqyfpd):춘봉박 내이놈!!!', '아리까ㄹㅣ (apfqyfpd)'],
#  ['45:40', '뽀삐냥 (mioioio):야 나 소름돋았어', '뽀삐냥 (mioioio)'],
#  ['2:07:03', 'oince3547:킹 맵', 'oince3547'],
#  ['1:08:12', 'disco4194:미 ㅡ리', 'disco4194'],
#  ['', '1:00:12', '너무하자너 (kht1906):ㅗㅜㅑ', '너무하자너 (kht1906)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:51:51'],
#  ['4:40:03', '꾸구꿀 (zerg0918):킹디디', '꾸구꿀 (zerg0918)'],
#  ['2:04:33', 'hamen2:대 크 트', 'hamen2'],
#  ['20:15', '트레이터 (skysyj117):필 리 핀', '트레이터 (skysyj117)'],
#  ['1:10:54', '항상조심해 (xzc325):관종듀옼ㅋㅋㅋㅋㅋㅋ', '항상조심해 (xzc325)'],
#  ['1:25:58', 'amgmtamgmtamgmt:카밀 승률낮춘건 잼구다', 'amgmtamgmtamgmt'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:38:32'],
#  ['3:55:17', 'holy1026:트할이 진짜 제일 못해', 'holy1026'],
#  ['3:47:31', '티엠티 (eldkqnfwh12):ㅋㅋㅋㅋ', '티엠티 (eldkqnfwh12)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:34:59'],
#  ['4:00:55', '라밤바_ (cyd9486):ㅅㄱ', '라밤바_ (cyd9486)'],
#  ['3:25:22', 'jsw0641:세주 각', 'jsw0641'],
#  ['3:46:08', '봉구몽구 (whatsupcu89):꼬갓', '봉구몽구 (whatsupcu89)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:05:26'],
#  ['53:16', '망고샴푸 (garnetring):과학', '망고샴푸 (garnetring)'],
#  ['2:00:13', 'qwer8888:전반은 못봣찌만 ㅋㅋㅋㅋ', 'qwer8888'],
#  ['3:15:25', '패러디 (kdk8361):묘비다 묘비!', '패러디 (kdk8361)'],
#  ['4:20:15', 'sang99246:슼또졌구나', 'sang99246'],
#  ['3:20:18', '빠삭한새우칩 (zero9566):방어율 보소 ㄷㄷㄷ', '빠삭한새우칩 (zero9566)'],
#  ['4:15:33',
#   '싹둑 (ssakdook):▣ 채팅방 상황에 따라 슬로우 모드 적용이 이루어질 수 있습니다. ▣ 비속어 및 도배 등에 대해서는 필터링이 진행 중이니 매너 채팅 부탁드립니다. (_ _) ▣',
#   '싹둑 (ssakdook)'],
#  ['4:22:38', 'OneHand31677:대놓고 어그로 끄네 에라이 정신병..', 'OneHand31677'],
#  [' 게시 시간 13:31'],
#  ['4:42:13', '샨드위지 (sandwizhi):?', '샨드위지 (sandwizhi)'],
#  ['4:21:24', 'shaksn3838:곰ㅡ보', 'shaksn3838'],
#  ['3:34:51', '여원 (illusion0416):와', '여원 (illusion0416)'],
#  ['1:41:06', '초보누에 (dksktkwl):와 빛맵 짱잘해 ㅋㅋ', '초보누에 (dksktkwl)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 50:11'],
#  ['50:55', '누누그만해 (wls3928):kt타임 ㅋㅋㅋㅋㅋㅋㅋㅋ', '누누그만해 (wls3928)'],
#  ['58:54', '침묵규칙 (2020tofhdnj):쥬 - 시 하라', '침묵규칙 (2020tofhdnj)'],
#  ['3:49:15', 'ansdnjs12:힐왜안찍냐', 'ansdnjs12'],
#  ['1:51:46', '잘됐으면좋겠다 (gkdltlzj):전투 아닐때', '잘됐으면좋겠다 (gkdltlzj)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:32:15'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:08:57'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 59:51'],
#  ['4:00:56', '여원 (illusion0416):개꿀잼', '여원 (illusion0416)'],
#  ['3:27:35', '나무깍는노인 (dkzlakfn):혜지야 강타말고힐들어', '나무깍는노인 (dkzlakfn)'],
#  ['22:57', '깜초 (kph2860):코 돈 빈 ㅋㅋㅋㅋㅋㅋㅋ', '깜초 (kph2860)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:35:23'],
#  ['2:41:01', '초코맛딱풀 (gluestick127):짐', '초코맛딱풀 (gluestick127)'],
#  ['1:45:26', 'smck05:대 퍼 타 임', 'smck05'],
#  ['3:30:12', 'YameKri:아니 이게 뭔짓거리야', 'YameKri'],
#  ['4:26:18', 'gozillason:"적"', 'gozillason'],
#  ['1:46:07', '불여우아리 (lovelin136):전요운 개잘하네', '불여우아리 (lovelin136)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:09:55'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:00:31'],
#  ['4:03:06', '이러면이제프로토스가 (khirai1):슼 미드 킬먹고 하는게 뭐냐', '이러면이제프로토스가 (khirai1)'],
#  ['3:43:27', '크산티노 (kimtino):빛구', '크산티노 (kimtino)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:35:56'],
#  ['3:34:51', '다닭 (ckdduq428):ㅁㅁ', '다닭 (ckdduq428)'],
#  ['1:45:22', '빻__빻 (cantataowo):대 ㅡ 퍼', '빻__빻 (cantataowo)'],
#  ['2:01:33', 'gerek010:녹턴궁 벌써 반이네 ㅋㅋ', 'gerek010'],
#  ['3:23:29', 'cherryblossom:팬들싸움이다', 'cherryblossom'],
#  ['36:12', '세이프티 (saint_lucia):또바나 노잼톤시절?', '세이프티 (saint_lucia)'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:31:17'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 24:01'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:50:56'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:17:07'],
#  ['3:49:57', '바꿔줘제발 (wlsdyd0505):무밍', '바꿔줘제발 (wlsdyd0505)'],
#  ['51:47', 'k1dl3ad3r:오우 갓리핀 지고있네', 'k1dl3ad3r'],
#  ['3:51:45', '욕은하지말죠 (nsjujje):소라카원딜 뫄냐 ㅋㅋㅋㅋㅋㅋㅋ', '욕은하지말죠 (nsjujje)'],
#  [' 게시 시간 18:54'],
#  ['4:04:49', 'preludeJJ:투할', 'preludeJJ'],
#  ['4:21:52', 'vjfjdfkqpf:ㅗㅜㅑ', 'vjfjdfkqpf'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 4:36:57'],
#  ['3:35:01', 'python00:이걸 혜지가?', 'python00'],
#  ['3:49:19', '달콤한정수씨 (ehw8042):커즈자랫네', '달콤한정수씨 (ehw8042)'],
#  ['3:34:40', 'rkaak33:이럴거면 자기 잘하는 챔 골라서 라인스왑하면 되는거 아니냐', 'rkaak33'],
#  ['45:30', 'nhlh7l:와', 'nhlh7l'],
#  ...]

# %%
lis1=[]
lis2=[]
for i in total_review:
    for k in i:
        if ':' in k:
            lis1.append(k)
    lis2.append(lis1)
    lis1=[]

# %%
lis2
# Out:
# [['4:06:27', '초보누에 (dksktkwl):와 진짜 꼬갓 넘넘 미쳤음 퍄퍄퍄퍄 ㅠㅠㅠㅠㅠㅠㅠㅠ 개머싯어'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 50:45'],
#  ['4:03:52', '남천동 (smartboy1203):ㄱㅈㅁㅁ'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 4:37:02'],
#  [' 게시 시간 33:49'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:32:48'],
#  ['3:56:55', '운타라최고다 (sogogi0816):갓구'],
#  ['3:41:53', '귀여운아롱이 (ero100):혜지 굿~'],
#  [' 게시 시간 5:24'],
#  ['3:24:25', 'jang2031:크 엳시 동준'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:04:03'],
#  ['52:48', 'IolFranco:야스오 바로리쉬중 ㅋㅋㅋ'],
#  ['1:50:19', 'arnapola:대ㅡㅡㅡㅡㅡㅡㅡ퍼'],
#  ['1:14:41', '차냥한다 (t53171213):????'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:02:15'],
#  ['4:04:25', 'naaaaamoooo:소라카도 하는거없어 왜픽함'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:33:09'],
#  ['1:58:36', '마트료제시카 (matroska94):장로 미췬'],
#  ['2:04:42', 'ggdog444:대퍼의 기적'],
#  ['3:52:20', 'exteriorglass:트할템머야 저거왜감'],
#  ['4:36:30', 'wbo0622:잼구 : 던짐'],
#  ['3:55:12', '밤에피는장미란 (kyant13):뱅 점멸힐 ㅋㅋㅋ'],
#  ['50:48', '선지쉐이크 (blessthief):대퍼타임'],
#  ['3:18:20', '제프티 (leinpols):얘들 신났네 ㅋㅋ'],
#  ['4:34:18', 'binstyle:?'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:29:14'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:47:39'],
#  ['1:01:53', '누가물어봄 (factattacking):?'],
#  ['29:51', '급진적페미니스트김경현 (very_hot_fire_fist_gombo_):미쉐린 + 용준좌'],
#  ['1:31:56', 'zcxv1234:대 동 빈'],
#  ['1:56:43', '만긍이 (rockman0810):2명이 덮쳐 ㅗㅜㅑ'],
#  ['2:10:52', '엔소르 (kieltre):이이이잉'],
#  ['4:31:02', 'omh1555:싱크 개판이네'],
#  ['2:14:56', '라무네 (likeingan):프로도 힘듬 ㅋㅋ'],
#  ['52:35', '침대인간 (applier):ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['1:09:19', 'eagleeye_mincheol:뭐냐아! ㅋㅋ 스포티비'],
#  ['2:23:42', '애비게일 (ymh708):케스팤ㅋㅋ'],
#  ['3:55:51', 'rpcn545:진짜 재밌다 ㅋㅋㅋㅋㅋㅋ'],
#  ['3:46:54', '천연밀가루 (wnsgur3638):??'],
#  ['2:03:02', '톡구99 (toesu2435):그 자리'],
#  ['4:17:36', '돌엄니칭구 (jch618):운타라 오랜만에 보여주라'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:25:09'],
#  ['3:52:33', 'jackgarba:PaoloCannone'],
#  [' 게시 시간 1:40'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:02:14'],
#  ['2:00:47', 'chunrae:근데 문도가 미드네'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 4:08:09'],
#  ['4:22:08', 'CleanSound:?뭐야 킹존 이겼네 그렇게 말리고'],
#  ['4:00:21', '갈매기 (instant0530):ㅈㅈ'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:04:50'],
#  ['1:05:25', '케빈 (rjssl1007):오프닝 개머싯다 ㄹㅇ'],
#  ['3:53:47', 'DivaPlay:SKT 울프 왜 안씀?'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:39:25'],
#  ['2:00:11', 'AEHYO:어제 왜 무슨일 있었음?'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:11:47'],
#  ['3:42:48', 'legendVQ:역시 세주 원챔충'],
#  ['4:42:17', 'beor1324:???????'],
#  ['4:40:30', '다유 (jsr132):ㅈ포폴트'],
#  ['2:02:17', 's4karis:그 위치'],
#  ['3:35:53', '닁닁낭낭 (limsor1229):어 우 슼'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:49:49'],
#  ['2:15:34', 'gh07233:자아성찰 ㅋㅋㅋㅋㅋㅋ'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:04:01'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 4:24:19'],
#  ['2:16:31', '드래곤라인 (bluvita1):스맵 여유있는척 ㅋㅋ'],
#  ['4:46:00', 'portablezerozero:퍼줬죠'],
#  ['1:18:01', '망고샴푸 (garnetring):노모 ㄷㄷ'],
#  ['4:09:22', '레이블_ (labelpaper):ㅠㅠ'],
#  ['52:31', '떡마귀 (rlarjsdnr100):이야 쥬시맨'],
#  ['3:36:47', '김읍읍 (killignstar):투할;'],
#  [' 게시 시간 2:15'],
#  ['34:11', '치킨2치킨 (verve1027):리멕전임'],
#  ['47:15', 'jueun12:롤챔스 개재밌다'],
#  ['4:32:47', '성문종합 (kksshv):캬'],
#  ['1:45:29', 'Onsaemiro42:기가 막히네 ㅋㅋㅋ'],
#  ['1:59:31', '으자 (frozen1205):엄'],
#  ['22:06', '까즈 (mgy2002):진에어 선 ㅋㅋ'],
#  ['1:37:42', 'kinggodmperor:타잔님ㅠㅠ?'],
#  ['47:54', '존야를눌러 (originaljhon11):즈엉상인데'],
#  ['54:50', '마늘맛사탕 (mymaks682):갓갓갓갓'],
#  ['44:16', '살상인 (kolin136):레넥기한 ㅈㅈ'],
#  ['57:31', '채팅안침 (kxv257):이제 도파가 전화로 피드백해준다 ㅋㅋ'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:21:08'],
#  ['3:19:14', '솔라리스 (sinhyg1):운타라가 발전좀 하지'],
#  ['4:01:04', '공기극딜 (spekdma):킹 갓 혜지 + 트할머니보쌈'],
#  ['1:01:04', 'A1ba27:1세트 누가땀'],
#  ['4:05:24', '마츠브 (jy970813):원딜 소라카ㅋㅋㅋㅋㅋ'],
#  ['4:17:35', '혀낙이 (jar5382):나도 안맞음'],
#  ['3:56:38', 'salromanchicken:ㅋㅋㅋㅋㅋ'],
#  ['3:34:35', '단탈리아묘아 (2retty2):소라카 봇은 뭔뎈ㅋㅋㅋㅋㅋㅋ'],
#  ['4:40:35', '방소상 (bangsosang):대대퍼타임'],
#  ['4:45:30', '나쎄존 (ddmina):풉'],
#  ['4:18:43', '못이기 (cant_victory):고 멘'],
#  ['4:26:20', '안녕하시나요선생님들 (kms423):이즈로 스웨인 절대못잡는데'],
#  ['2:00:04', 'zmrsl:대퍼라서 모른다'],
#  ['1:31:44', "이겜해보고싶어 (geeasdf):이게 바로 '국가대표'다"],
#  ['1:09:59', '싫은날 (cocopopp6714):kt가 잘 준비했네'],
#  ['1:39:13', 'minimaxmized:바람의 전학생인가'],
#  ['55:32', '꼬마티슈 (asmona):신고식담당'],
#  ['4:40:59', '항상조심해 (xzc325):에포트 진짜 노답'],
#  ['3:29:52', 'rlatjdxo3cm:슼이 그냥 이기겠네 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['1:33:43', 'qlqh9090:ㅁㅠ'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:24:09'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:05:06'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:52:10'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 27:34'],
#  ['3:55:11', '조제해적단 (kgoku648):개재밋네 진짜로 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['3:49:35', 'lafion:잼구 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['48:54', '현쓰훈트 (dongsk89):ㅋㅋㅋㅋㅋㅋㅋㅋㅋ용카이팅'],
#  ['41:16', 'jihaes2:이대로가면 그리핀이 중국 씹발라주려나'],
#  ['50:48', '에버다이 (whgusdnr1984):대퍼타임'],
#  ['1:13:24', '_이타카 (wjswkdrms7):아트를 안하고?'],
#  ['1:47:30', '얼어붙은왕국의룩공얍 (carta987):아 진짜 개웃기네 ㅋㅋㅋㅋㅋ'],
#  ['38:56', '닿기를 (rhrnfu2002):알파카 본체 나왔다.'],
#  ['1:03:39', '합스부르그 (kjh8207):왜 모닝임? 오후 경기 아님?'],
#  ['2:10:50', 'Sweetsay:이이이잉'],
#  ['1:57:49', 'draliay:한타의 KT'],
#  ['21:33', '잘됐으면좋겠다 (gkdltlzj):ㄷㄷ'],
#  ['1:46:00', '따워 (rktower010):다리우스 궁 계속 박는거봐라 ㄷㄷ'],
#  ['2:16:02', '문별이_ (yooa0917):패기좋노'],
#  ['3:59:10', '큰빛나리 (kth0070722):ㅁㅁ'],
#  ['2:00:10', '공식 (tlqpffjadk1):ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['3:43:42', '튜비 (wnrks12):갓구 떡상 왓다'],
#  ['53:59', '우닭이 (wallgung):미드이렐은 똥이다.'],
#  ['2:18:21', '서네서네 (tjstjs55):전패는 있다!'],
#  ['4:46:01', 'wer3162:오 문도 ㅋ'],
#  ['1:36:47', '에버다이 (whgusdnr1984):용컨 ㄲㅂ'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:15:28'],
#  ['3:39:46', 'c2212:갓구'],
#  ['3:34:02', 'dfcxz:롤 실화냐??'],
#  ['4:24:53', '아리폰 (aripon):팀 솔로 미드!!!!!'],
#  ['3:46:03', '희섭 (khsdfg952):판정 오반데?'],
#  [' 게시 시간 32:56'],
#  ['3:59:06', '신세카이 (mlb5021):플 뺏다'],
#  ['3:16:41', '차캐요 (baksick2):나 왜 갑자기 싱크 안맞지'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 24:30'],
#  ['1:26:09', '_이타카 (wjswkdrms7):왜 여기는 바위게 먹은 횟수 안뜸?'],
#  ['2:09:14', '아랏따 (kkrbng):그리핀 왜 졋냐 ㅋㅋㅋ'],
#  ['3:42:56', '소금맛설탕 (rlathfrl12):004 ㄷㄷㄷㄷㄷ'],
#  ['3:19:07', '프카 (ehdtkdhkd):에포트 잘나왔네'],
#  ['24:34', '갤러거 (mugulchrome):쉔밴 맞지'],
#  ['1:17:30', '블루쵸파 (bluechopa):바이퍼가 할게 너무 없당'],
#  ['3:24:44', 'k1dl3ad3r:킹존 승 !'],
#  ['3:25:01', 'little8oy:페이커만 막으면 스크는'],
#  ['2:26:10', 'yabby:ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ이것은'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:51:11'],
#  ['4:34:14', 'cho10987:시간 개손해아닌가'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:15:03'],
#  ['3:44:46', 'sonete77:와드'],
#  [' 게시 시간 20:51'],
#  ['4:28:09', 'zoqxlsgh:뚜벅이 조합이냐? ㅋㅋ'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:41:01'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:51:27'],
#  ['1:15:47', 'golizerd:1위를 #뒤집어버려 kt (korea team)스코어도 2대 0'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:53:29'],
#  ['4:29:35', '똥개래 (gotjrdl11):뱅기 ㅜ'],
#  ['4:33:39', '김과일 (ksdo3923):ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['3:55:29', '직업트수 (mylife_for_twitch):뱅크드 바이 맘'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:05:17'],
#  ['3:48:38', 'Spvls0613:잼구 ;;'],
#  ['1:36:19', '장서켠 (koover4):케이티는 폰 버린게 신의한수임'],
#  ['1:31:49', '담백한버터 (toyou35):ㅋㅋㅋㅋㅋ'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:27:00'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 4:01:31'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:07:08'],
#  ['1:45:14', 'sg01312:한타의 그리핀 ㅅㄱ'],
#  ['54:03', '콜라쫌 (woosung0123):ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 그 귀환'],
#  ['4:33:52', '시바리수 (xkdlrj010):ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['3:40:39', 'gkswngjs12:칸무룩'],
#  ['2:04:12', '왼잽이 (jyi1328):담당일진'],
#  ['4:12:52', '루티엘 (catcrawn):갓프닝'],
#  ['1:58:45', '당근순 (mj4421):슈ㅡㅡ퍼'],
#  ['47:25', 'kspc2:5인도발 미쳤어'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:20:04'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:43:35'],
#  ['2:16:00', 'JoYuneHo:벌써 2000년대 생들 나오네'],
#  ['4:03:59', '귀족갈비 (thsdydgus123):도도갓...'],
#  ['1:59:02', 'cravenimp:이속봐 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 48:52'],
#  ['3:15:16', '은신님_ (heyolock):Bengi ㄷㄷㄷㄷ'],
#  ['3:54:32', '김소혜 (lhj0103kr):폐'],
#  ['54:54', '햄스터 (windec22):쥬시하라'],
#  ['4:26:34', '월계수나무 (amg1682):아 제발'],
#  ['2:15:51', '팬더머가리 (www3493):저 얼굴이 2001년...?'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:31:17'],
#  ['46:48', 'o0o0o0:유칼 쩔ㄹ었땈ㅋㅋㅋ'],
#  ['3:30:32', 'sang99246:구와악'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 4:28:39'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:48:01'],
#  ['1:51:58', 'ycjj:모렐로있는데 ㅁ?'],
#  ['1:07:49', '엑스펙스 (bydream11):크'],
#  ['3:44:33', 'veresk777:'],
#  [' 게시 시간 27:59'],
#  ['59:08', '엘리트마법가루 (wietle):머 주시하라만 하면 다 죽네'],
#  ['29:24', '클로렐라쌀밥 (whtlaehd123):초ㆍ비 야스오도 잘하던데'],
#  ['50:49', 'dhkim1268:대퍼타임마'],
#  [' 게시 시간 31:26'],
#  ['2:04:58', 'ai234:담당 일진 ㅋㅋㅋ'],
#  ['1:53:17', '스졸렬 (mlli1412):데프트 ㅋㅋ'],
#  ['1:36:05', '외가 (aorbint56):누강 강팀인지 알수 없게 되어버린 개족보가 된거지..'],
#  ['3:15:13', 'deuxmj123:이거 노래 머임???'],
#  [' 게시 시간 14:35'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:08:15'],
#  ['3:46:17', '갈릭버터맛우결충 (kphsws):혜지가 미쳤네 갑자기?'],
#  ['1:50:18', 'shangus01:대ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ퍼'],
#  ['4:18:02', '엉덩이안의정의 (zazaxs):ogn 사내 커뮤니티'],
#  ['4:03:24', '트위퍼 (vert_pomme):ㅈㅈㅈ'],
#  ['1:10:49', 'nadajun1:용준좌 실성'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:33:19'],
#  ['1:07:56', '자칼54 (na6game):빛코어 수듄'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:22:44'],
#  ['3:59:28', '깜오 (magi19238):이게 귀환이지'],
#  ['4:42:19', 'cakeisspy123:뭐함'],
#  [' 게시 시간 5:55'],
#  ['3:39:43', 'SINISE77:킹구'],
#  ['4:09:49', 'qkdldhslzjf:ㅁㅊ 브금 ㅋㅋㅋㅋㅋㅋㅋ'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:52:14'],
#  ['1:00:06', '다임구혁 (gurdyd9):으앜!!!!!!!'],
#  ['21:36', 'goodchu:황 비 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['3:50:15', '나랑빠데하카 (wbsldjalswo):18섬머 세체미는 이안이다..'],
#  ['4:18:21', '핵뚠뚠 (hogcat_):ㅇㅈ 경기 꿀잼이었다'],
#  ['3:37:30', '송용준의오른손 (ckd227):블랭크개트롤ㅇ네진짜'],
#  ['4:04:59', '우물이 (ssimsangi):미드 개못함'],
#  ['2:12:59', '쫑그 (gyu05303231):다나까ㄷㄷㄷㄷ'],
#  ['3:34:49', 'zmfl1234:듣보'],
#  [' 게시 시간 0:25'],
#  ['1:59:27', 'gks414:무몬뎈ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:02:21'],
#  ['4:33:35', '성적호기심 (sup8072):표정ㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 45:24'],
#  ['3:47:30', '욕망덩어리 (yogmang):소라카????'],
#  ['1:12:46', 'goewon:무신 젠지냐'],
#  ['3:59:22', '크보후퇴 (then2f):혜지야 너 잘하고 있어!'],
#  ['1:07:39', '0unG0101:야그라미 갓살표 ㄷㄷ'],
#  ['52:21', 'hakodate777:야소 리폿좀'],
#  ['1:07:08', 'buffadpls231:쥬시하라'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:49:28'],
#  ['32:42',
#   '싹둑 (ssakdook):2018 LoL 챔피언스 코리아 섬머 : 6월 12일 ~ 7월 1일 / 7월 11일 ~ 8월 2일 / 8월 4일~ 8월 9일 ▣ 매주 월요일 휴무'],
#  ['1:50:29', 'sh6563:문도가 진짜 혐도다혐도;;;;;;;;;;;'],
#  ['1:51:19', '뭐되더놈 (illegalp1):이걸 대퍼하네'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:10:55'],
#  ['28:29', '테일러 (bp_tailor):바이퍼 라이즈 나오나?'],
#  ['2:58:33', 'nowrock59:어디 해설인가여'],
#  ['4:27:39', 'helloalone:ㅈㅈ'],
#  ['3:30:05', '우노_우노 (skadbsgh123):ㄷㄷ?'],
#  ['4:34:22', '제로콜 (c0cac0lazer0):ㅋㅋㅋㅋㅋ'],
#  ['52:31', '말리킴 (yooni0819):와 미쳤다 ㅋㅋㅋㅋㅋㅋㅋ'],
#  ['3:42:38', 'fullinlove486:슼 대승리 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:43:56'],
#  ['3:19:42', 'k1dl3ad3r:LLLLLLLLLLLLLLL'],
#  ['2:31:51', 'roh468:네 그리핀이 이김'],
#  ['1:10:15', '트위치마니보는사람 (twitchjoaing):신입생 폭격기 무엇'],
#  ['23:55', '우리형이야왜그래 (nionhar):띵장'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 4:34:01'],
#  ['4:15:49', 'ingyu_mom:패슼슼 가즈아~!!!!'],
#  ['31:10', 'nhlh7l:겨털노출'],
#  ['3:44:05', 'kissmac:칸 꽁으로 한번살고 3데스'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:09:30'],
#  ['1:43:14', 'IDandyAndyI:대ㅡ퍼'],
#  ['1:59:26', '엉덩방개 (audrn156):아 광고 진짜 젼나많네 들어올때마다 있네'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:32:45'],
#  ['3:42:54', '풍댕이엉댕이 (tkdkr12):ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['4:39:34', 'dkffkels482:형들ㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['37:16', 'kangjw0403:8.12'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:37:49'],
#  ['1:01:09', 'zmrzmzmr:진짜 딱 매123갈들이나 쿰123척거리면서 좋아하겠네 ㅋㅋ'],
#  ['2:18:26', '조강현은모두의것이니까요 (joganghyun_is_everybody_s):킅트와 슼트 무너졌네'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:19:05'],
#  ['2:01:16', 'east_tiger:슈---퍼팀'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:11:11'],
#  ['50:48', '이제원 (jwlee04231):대퍼타임ㅋㅋ'],
#  ['2:27:15', '리롱띠 (tkdlgk1):앗..아아 스코어'],
#  ['4:08:13', '동원마일드참치 (hdlee2312):구와앜'],
#  ['4:45:51', '망고샴푸 (garnetring):트할 4킬 먹고시작했는데 왜이리됐냐?'],
#  ['4:42:43', 'adoong00:550'],
#  ['1:59:31', '징쥥 (tgi1213):엄?'],
#  ['3:46:57', '전찬 (jjj5530):까비'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 4:16:48'],
#  ['57:45', '돚거입니다 (nkh0417):도파충 좀 ㄲㅉ라'],
#  ['3:24:05', 'o0o0o0:형모야 부탁해'],
#  ['3:58:00', '프리즈비슬라이더 (youna40):트할은 진짜 뜬금사 좀 어떻게 피드백 안되냐? 맨날 혼자 죽어 아놔....'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:14:42'],
#  ['3:51:07', '저급어그로 (ekekr):왜 깝침 ㅋㅋ'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:33:15'],
#  ['2:16:56', 'cactusstick:ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['4:33:55', '행복수비 (crazyzerg2):나라잃은 표정'],
#  ['49:08', '체력왕김피곤 (badboy9467):아무리 그리핀이라도 이건 힘들다 진심 ㅋㅋㅋㅋ'],
#  ['4:16:52', '민딘이 (dlrcoel):저거 지분 트할7 블랭크3 ㅇㅇ'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 56:25'],
#  ['4:07:31', '히바나온나나 (rrribbit0805):1+1 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['53:57', '메이플좋아 (koreakso):그 귀환 ㅋㅋㅋ'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:45:48'],
#  ['4:44:39', '혀낙이 (jar5382):싱크이상함'],
#  ['2:58:46', 'nowrock59:오 굳'],
#  ['1:37:25', "방송좀잘해봐 (zz930128):'그' 리핀"],
#  ['1:31:51', '알라인 (allein94):스고수~'],
#  ['1:10:42', '영재짱1 (poweryj):ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['3:37:20', 'Freyja738:트할잘못임'],
#  ['2:00:13', '룩삼_쪼아 (looksam_jjoa):전반은 못봤지만 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:21:19'],
#  ['2:03:09', '데코즈 (decoz91):근데 오늘 그리핀은 왜 이리 픽을 불리하게 뽑지'],
#  ['1:31:47', '코노스바우주명작 (ljyong0303):국 대 정 글'],
#  ['3:20:10', '넥스트 (nagihara):커즈는 나온적이 없어서 저런가'],
#  [' 게시 시간 12:20'],
#  ['1:59:00', '지나가는지렁이 (holicoo):korean team win'],
#  ['38:37', '망고베리 (hyuuunj):d'],
#  ['1:55:54', 'apane12aa:클피셜) 그리핀>>KT'],
#  ['2:03:05', 'kangjw0403:마따 머합니까?'],
#  ['3:35:54', 'silver1429:띠용 비디디 왜 저깄음'],
#  ['4:32:51', '브래포드 (fnstmzkdl12):페이커 ㅠㅠㅠㅠ'],
#  ['1:00:48', '범닭 (gg9185):이거 2~3세트 하루나와서 젠지가 이김'],
#  ['2:15:30', '포장용아이스팩 (raum_9114):ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  [' 게시 시간 0:20'],
#  ['3:19:06', '홍방귀 (ysj991105):전력?'],
#  [' 게시 시간 3:37'],
#  ['3:42:45', '서폿빼고다갑니다 (harrybbwe):갓구나이트'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:38:30'],
#  ['3:34:21', '물약자판기 (ileisamsa):     '],
#  ['3:37:13', '장4장 (jang4jang):트할 뭐하냐'],
#  ['4:17:25', 'kimdj342:블랭크가 뭘 망침'],
#  ['55:03', '김씨닷 (kimcdot128):담당일진 ㄹㅇ류'],
#  ['3:45:37', '쿠라란 (albanlid):아깝다 그 귀환'],
#  ['4:38:49', 'jang2031:그래 잼구야 뭐 이상한거 하지말고 걍 용 먹어라'],
#  ['23:47', '모케 (hollowpiece):kt팬 많을건데 걍 찍어눌럿네'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:33:57'],
#  ['2:27:05', '나에게키보드만있었더라면 (qwerty_asdfgh_zxcv_steelo):페이커 깜짝 출현 ㅋㅋㅋㅋ'],
#  ['1:00:21', 'k000ooo:큐베 간큰거 보소'],
#  ['3:32:37', 'iris21c:소라카원딜?'],
#  ['2:18:05', 'Chamring:2대떡'],
#  ['4:40:30', '슬렛 (kjy14224):개싸움ㅋㅋㅋㅋㅋ'],
#  ['1:42:43', 'meanprize:??'],
#  ['4:36:58', '할거없긔 (ijhijh78):또간다'],
#  ['2:05:00', 'buffadpls231:그리핀 하위팀'],
#  [' 게시 시간 12:52'],
#  ['1:15:02', 'goewon:다주냐'],
#  ['46:26', '슬리퍼는삼디다스 (hmc9909):JUICY 하라'],
#  ['3:46:19', 'plus3631:바텀차이진짜어마어마하다'],
#  [' 게시 시간 12:14'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:54:18'],
#  ['1:50:44', '티모장인 (sky0331):문도 무적 ㅋㅋㅋㅋ 개사기 ㅋㅋㅋㅋㅋ'],
#  ['19:54', '올란두 (zialng):그리핀 1패 누가 만들어줄까?'],
#  ['4:34:20', '침대위의메르시 (mercy_on_the_bad):ㅋㅋㅋㅋㅋ'],
#  ['3:36:41', 'Spvls0613:?'],
#  ['1:48:50', 'kisalute:각.개.전.투'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 4:23:55'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 4:40:45'],
#  ['1:00:10', '설뤼반 (ddholic):프레이는 가장도 아닌데 왜그러는거냐...'],
#  [' 게시 시간 18:30'],
#  ['4:24:03', '포케모온마스또 (ehs57111):3:3임?'],
#  ['3:31:05', 'dreaming9436:이게 전략겜이지'],
#  ['4:33:37', '고래구마 (baleine532):ㅋㅋㅋㅋㅋㅋㅋ'],
#  ['3:46:53', '나의주 (denebollacan):서폿차이가 좀심하긴하네'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:13:02'],
#  ['3:54:24', '아네모 (yujining0628):소리 싱크 왜이러지'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 4:03:48'],
#  ['3:40:31', 'extracter1:갓구나이트;;'],
#  ['1:46:58', 'vqhtm12:초비 조이는 필밴이여'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:52:01'],
#  ['4:40:35', 'msj98:ㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['3:43:37', '신구__02 (singu__02):킹갓제너럴갓구'],
#  ['4:00:47', '버퍼링좀고쳐줘 (whwns3521):그건좀'],
#  ['27:08', '오늘밥은치킨 (a991213):ㅡ스'],
#  ['1:16:06', '긍정멘탈소환사 (johanhee7):쵸비의 조이라면 ㄹㅇ 믿을 만 하지'],
#  ['4:02:52', '힘내라너구리 (mybee1208):소라카 침묵즉잘이 좋아서 쓰는건데 이건 너무 쎄서 의미가 없어졌넹..'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 4:29:55'],
#  ['1:42:40', '나에게키보드만있었더라면 (qwerty_asdfgh_zxcv_steelo):??'],
#  ['3:30:35', 'rkaak33:라칸 정글이야?'],
#  ['2:29:32', 'whrtldn90:빠따'],
#  ['1:02:13', 'H4ZE33:한화스폰ㅋㅋㅋㅋㅋ'],
#  ['3:18:32', 'jang2031:헐 커즈 나왔으면 슼 졌네 ㅠㅠ'],
#  ['4:32:55', 'kangksh123:오늘갓구...'],
#  ['3:42:09', '돼지를보면짖는개 (nuri489):이펙트 보인것 같은데'],
#  ['1:19:00', '원앙이 (kof9494):크트 밴픽 너무 잘햇는데?'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:38:59'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:21:10'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 4:09:58'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:57:26'],
#  ['3:55:03', 'jih675:페이커는 페이커다'],
#  ['4:10:28', '웡석 (jws0356):비가 많이 온다..'],
#  ['1:41:31', 'Kimwoori:ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['4:32:55', 'adoong00:갓구'],
#  ['21:33', 'ccc3274:이게 뭐야'],
#  ['2:26:15', 'JHPSoft:ㅠㅠ'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 45:05'],
#  ['4:47:13', '차캐요 (baksick2):에포트 cs 안주네 ㅋㅋ'],
#  ['3:47:43', 'SmRIa:오또케 오또케'],
#  ['3:49:02', '노말박 (wjdalsqkr):우리혁'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:25:35'],
#  ['33:18', 'ZXC3787:잼리오 개꿀잼'],
#  ['1:56:35', 'gino9940:태양을 등진곳에서...'],
#  ['3:34:40', 'rkaak33:이럴거면 자기 잘하는 챔 골라서 라인스왑하면 되는거 아니냐'],
#  ['1:53:03', 'one141:kt 승 패패 ㅋㅋㅋㅋㅋ'],
#  ['4:00:30', 'allru:트할던지네 ㅋㅋㅋㅋㅋ'],
#  ['3:46:01', 'beautea37:떡락'],
#  ['3:51:06', '천칭별 (pjh71042002):ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['2:11:56', 'FLV_Spirit:ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['4:06:19', '2215:벤픽이 망했음'],
#  ['3:34:51', '노빈손 (sakura605):와 고릴라'],
#  ['3:50:32', '앙앙이요 (lcspolo):페이커 궁키고 q 맞고 딜로스 실화? 풉ㅋ'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:53:02'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:50:32'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:17:29'],
#  ['2:15:41', '예술은길고 (pak0120):체 ㅡ 득'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:47:14'],
#  ['4:20:45', 'wugef:페이커속마음) 아 팀운,,,'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 4:47:15'],
#  ['1:47:30', 'msj6278:한타의 대퍼'],
#  ['3:46:59', '예솔이 (sdf045):고ㅡ멘'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 45:18'],
#  ['58:04', 'ath2:zzz'],
#  ['1:10:59', 'holy1026:부장님'],
#  ['1:50:20', '항문궤양 (pmin5432):킹도 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 4:34:52'],
#  ['30:39', 'hmhee07:근육돼지들대결'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:40:54'],
#  ['58:05', 'mircle94:다이겼는데 거품이래 ㅋㅋ'],
#  ['1:22:43', '과몰입씹가능 (ssg1994):리쉬 ㄱㅅ'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 4:00:12'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 19:39'],
#  ['2:19:50', '날좋아하는거알아 (mck9191):리라정도는 LCK 8위선에서 해결되지'],
#  ['3:29:29', 'remind2017:닷지유도'],
#  ['2:24:38', '킴민2 (rlatmdals101):누가이겼나요?'],
#  ['1:51:12', 'Wlgh2022:ㅂ똥칼 ㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['1:05:04', '코노스바우주명작 (ljyong0303):더 정 글 사 마 ㅠ'],
#  ['1:10:38', 'lee99082:아...'],
#  ['3:57:20', '문디멩뿌아 (koo02208):이거 무슨 핑퐁입니까? 에포트 제물입니까?'],
#  ['55:35', '도사전우치 (toriljs):도장깨기는 끝낫나?'],
#  ['4:00:07', 'sw13mmer:고릴라이프 화이팅'],
#  ['3:51:47', 'prayfor3:재밌다ㅋㅋ'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:01:54'],
#  ['4:26:36', 'skun35:또리우스 ㅋㅋ'],
#  ['1:58:37', 'rpcn545:캬 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['2:02:08', '심이부러진연필 (hsy4428):유도 ㅋㅋ'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:56:34'],
#  ['4:29:06', 'naaaaamoooo:밴픽 부터 졌어.... 뭐하냐'],
#  ['53:12', '담흑 (leesu1012):ㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['4:27:03', '민트랑 (imoa1123):신짜오 ㅠㅠ'],
#  [' 게시 시간 7:17'],
#  ['3:44:22', 'xhfldjq:잼구'],
#  ['4:29:49', '따옥 (checkclean):ㅋㅋ'],
#  ['3:59:42',
#   '싹둑 (ssakdook):▣ 채팅방 상황에 따라 슬로우 모드 적용이 이루어질 수 있습니다. ▣ 비속어 및 도배 등에 대해서는 필터링이 진행 중이니 매너 채팅 부탁드립니다. (_ _) ▣'],
#  ['1:58:21', '카레다음깍두기 (curry5939):케넨궁 속이시원하네~'],
#  ['4:01:48', 'r_e_m_u:소라카 1위 ㅋㅋㅋ'],
#  ['4:00:33', 'kingjongwoo:페이커 뭐함 ㅋㅋㅋㅋㅋ'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:21:50'],
#  ['1:45:07', 'audtjr44:대 퍼'],
#  ['57:06', 'golizerd:#뒤집어버려'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:48:59'],
#  ['3:27:02', '먼지탱이2 (kyj3891):어쩌라고요'],
#  [' 게시 시간 10:00'],
#  ['4:11:33', '우리형이야왜그래 (nionhar):킹존이 이겻다'],
#  ['4:38:14', '공익따무새 (gongikdda):앗 cs'],
#  ['1:46:24', '타마냥 (dltjdqja726):잼이'],
#  ['45:31', '트위치마니보는사람 (twitchjoaing):ㅁㅊ'],
#  ['1:37:38', 'erd5396:대퍼했다'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:26:10'],
#  ['46:08', '차캐요 (baksick2):저걸 기어코잡네 ㅋㅋ'],
#  ['1:53:53', 'skwmghkdud47:이게 해설이지'],
#  ['2:18:48', '파반느 (dengo2611):STK T8'],
#  ['3:21:40', '당황마침착해 (hahazic):요즘도 얼굴로 겜하나'],
#  ['2:02:19', 'givemetip:녹턴밴 안한게 이렇게'],
#  ['2:07:37', 'qlqh9090:스고수 하이라이트'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 47:54'],
#  ['3:48:41', '곰대장 (bong5632):잼구 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['3:41:18', '서쉘 (sershell12):그리핀 0:2로 졌어요'],
#  ['4:00:40', '단_화 (l2o2):?'],
#  ['4:01:33', 'sinc1029:으 토나온다 트할에포트 둘이 완전 설사폭풍'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:42:36'],
#  ['3:35:33', '클로델 (timeslip05):bddㅋㅋㅋㅋ'],
#  ['1:53:23', '헷지입니다 (kimse1005):혐-도'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:34:16'],
#  ['2:40:37', '타타타다 (minoo0716):오예'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:36:22'],
#  ['3:58:19', '아마맑음 (osd6808):몰가님?'],
#  ['3:45:14', '하와수 (chb8914):불ㅡㅡㅡ편'],
#  ['28:33', '킬리안음바페 (zlffldksdmaqkvp):무당준 ㄷㄷ'],
#  ['54:16', 'cgh310:갑분쉔'],
#  ['3:50:49', 'kim941213:동 수 칸'],
#  ['1:50:30', 'jsy9898:대-------------퍼'],
#  ['3:24:47', '푸시딘산나트륨 (lds1515):페이커 살아 있네'],
#  ['3:49:17', 'blackcloud9:페이커 무빙 미친..'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:04:56'],
#  ['3:35:24', '버닝 (qwsa302):아'],
#  ['1:45:23', 'KOR1221:기가 막히다'],
#  ['4:05:04', '수감자45 (prisoner45):어유 저 밉상 자가'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 4:05:25'],
#  ['54:31', '코크판다 (cokepandaa):대퍼 타임 ㅋㅋㅋㅋ'],
#  ['3:40:35', '죄송해요손 (zxc996):킹갓구'],
#  ['4:01:12', '쟈스민향기킁킁 (qchaeqchae):점멸 뭐하냐'],
#  ['4:00:48', '욕은하지말죠 (nsjujje):트할머니 응디디 ㅋㅋㅋㅋㅋㅋ'],
#  ['3:26:15', '예솔이 (sdf045):혜지가 뭐여?!?'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:43:00'],
#  ['4:27:08', '기린아저씨 (gaejo9):문도'],
#  ['2:09:22', '부시밍 (boosiming):싱크안맞노'],
#  ['4:29:29', '급진적페미니스트김경현 (very_hot_fire_fist_gombo_):다데 ?ㅋㅋ'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:23:28'],
#  ['3:59:08', '쿠르쿠르 (bluemoon287):ㅁㅁ'],
#  ['3:23:22', '잼구나이트 (ejqmf92):skt 화이팅!!!!!!!!'],
#  ['3:48:40', '루크로이 (jgj1807):잼구'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:55:12'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:42:37'],
#  ['3:38:43', '수수옥 (ok971010):지나갑니다'],
#  [' 게시 시간 33:43'],
#  ['13:35', '윤갑이 (jood3021):오늘 킹존한테 지면 skt 해체인가 ㄷㄷ'],
#  ['2:02:11', '윾두의권 (fist_of_nipple):왜냐! 윾도 미사일이라서!'],
#  ['4:32:05', '쿠리밍 (naong0126):컨트롤w누르면되여'],
#  ['2:17:27',
#   '싹둑 (ssakdook):2018 LoL 챔피언스 코리아 섬머 : 6월 12일 ~ 7월 1일 / 7월 11일 ~ 8월 2일 / 8월 4일~ 8월 9일 ▣ 매주 월요일 휴무'],
#  ['3:37:00', 'ksg107808:ㅁㅊ네'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:41:10'],
#  ['3:54:16', '게으름벵이 (rhkswkr7):운타라 왜 안나오징'],
#  ['45:33', '쿠르쿠르 (bluemoon287):쥬ㅡㅡ씨'],
#  ['37:32', 'dolphin3266:14'],
#  ['55:19', 'Wlgh2022:뽕뻐지냐!!'],
#  ['19:54', '이모카스주세요 (skh2938):케이티 전투력 측정기행 ㅋㅋㅋ'],
#  ['4:06:02', '오크니즘 (orcnizm):에포트 트할 탓이지. 퍼블 주고 탑에서 못 잡고'],
#  ['57:15', '나는너가참좋다 (flgh):갓트록스님 은퇴경기 ㅠㅠ'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:45:49'],
#  ['4:21:12', 'kdh4649yo:근데 트할도 트할이지만 봇 듀오가 발ㄹ려서 고릴라 발이 풀렼ㅅ다는게 펙트'],
#  ['1:11:37', 'JoYuneHo:쥬 씨 하 라'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 4:15:04'],
#  ['3:29:37', 'kyoda0607:닷지'],
#  ['4:44:23', '한양양장점옆한영양장 (puorkme):ㅇㅇ 커즈 잘함'],
#  ['3:34:52', '다람쥐99 (gk0846):ㅁㅁ'],
#  ['3:14:17', 'ehddnjs9081:우리게이 삼행시 할 줄 모르노'],
#  ['1:50:20', '오잉칸 (scom804):동수칸'],
#  ['4:08:55', '진세이파츠는호피팬티 (wjsiuy):가장의 무게..'],
#  ['1:51:40', 'bini9636:용치고 있어서 떨어졌는데 그걸 싸우고 있네 밥통 kt'],
#  ['3:47:57', 'redpanda1797:ㅁㅍ'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:18:40'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:26:25'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 4:37:56'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:28:50'],
#  ['4:03:45', '섹시주안 (eclair731):재밌었따 ㅋㅋ'],
#  ['3:39:27', '도루코대검 (sjsmscksdn):음? 4서폿?'],
#  ['4:33:32', 'classes7:동 수 칸'],
#  ['4:42:43', '라플라스 (sagekyo):밀리는데?'],
#  ['4:23:33', 'wooking12:크트 그리핀 누가이김??'],
#  ['20:13', '우리형이야왜그래 (nionhar):앙 초비다'],
#  ['1:51:13', '랑벨 (smillhm):쥬시... 으으악'],
#  ['1:17:56', 'seegoale:노모 ㅋㅋㅋㅋㅋ'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:46:51'],
#  ['1:39:59', '사랑은카레의노예 (tksclvlscl):금다이아 준위 있음'],
#  ['3:29:32', '웃우 (misgnomer):호옹이 블리츠'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:57:08'],
#  ['46:56', '공기극딜 (spekdma):와 갈리오 아트록스 예술이네 진짜'],
#  ['4:09:38', '수수수웁 (dlatnqlstpa1):ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['4:39:53', '캬하하헬퍼아니야 (netnetll2):ㅈㅈ'],
#  ['55:54', 'ckc1545:도장깨기의 맛을 보았느냐?'],
#  ['3:18:29', 'bluing11:미드빵햇네'],
#  ['1:57:57', '무루리 (alswns2893):장로 탈피'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:30:14'],
#  ['1:38:46', '마믹 (ma1mix):스코어를 만난것 자체로 타잔 디버프 ㅎㄷㄷ'],
#  ['3:51:22', '공기극딜 (spekdma):뭐냐 게임 왤캐 싸우냐'],
#  ['3:53:03', '마비노오비 (qwas0579):자야 15렙이네 ㄷㄷ'],
#  ['4:17:25', 'project00801:내가 1경기 때부터 싱크 지적했잖아. 귓등으로도 안듣더니 ㅉㅉㅉㅉㅉ'],
#  ['2:26:02', 'Chamring:또죽냐'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:17:12'],
#  ['47:07', '이겜해보고싶어 (geeasdf):55도발 이 돌크리트놈들ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['3:39:46', '야뿌야뿌 (esyzy96):리쉬 ㄳ'],
#  ['4:32:58', '테일러 (bp_tailor):오늘만큼은 갓 구다'],
#  ['4:14:53', '어쌔 (assassin5856):싱크 아까 게임때부터 안맞던데'],
#  ['54:29', 'gomseulgi210:?'],
#  ['4:40:32', 'somemore20:엉망이네 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['3:17:54', 'haha168866:可和'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 47:29'],
#  ['1:50:38', '봄사과 (refresh_mind):ㅋㅋㅋㅋㅋㅋㅋㅋㅋ 킅 아무고토 못하네'],
#  ['54:48', '사상빨간_사춘기 (mx470):쥬씨하라'],
#  ['2:00:10', 'jing071776:ㅠㅠㅠ'],
#  ['39:45', 'smile0420:아직까진 좋다'],
#  ['3:26:15', '강윤님 (doompest1):오빠 나 뭐하몀ㄴ돼'],
#  ['3:19:29', '덴젤커리 (kty4309):트할 팔뚝 ㄷㄷ'],
#  ['2:14:20', '리따이준준 (dkwmqkffldna):2:0'],
#  ['3:55:00', '말미 (hiu1012):ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['3:52:59', 'gabrielsukidayo:정글에 카카오,엄티가 있다면 서폿에는 에포트,울프가 있다 ㅇ ㅣㄱ ㅣㅇ ㅑ'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:40:10'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:15:00'],
#  ['4:36:46', '문어단대장 (applejamtoast):지독하다'],
#  ['2:18:33', '타타타다 (minoo0716):5위 6위 순위 바꿨뇨'],
#  ['3:43:26', 'ritzstar7:처형당할뻔 ㅋㅋㅋㅋ'],
#  ['2:18:15', '포장용아이스팩 (raum_9114):ㅋㅋㅋㅋㅋㅋㅋㅋ케이티스럽게'],
#  ['1:26:03', '대디 (yi1214):그리핀 질듯'],
#  ['1:51:02', '포코라 (pokora3823):혐도 ㅋㅋㅋ'],
#  ['3:21:50', 'hochani:ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['1:53:35', '섹순신 (story7676):문도 너프좀'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:12:21'],
#  ['3:21:44', 'dkffkels482:100한 이미지'],
#  ['48:14', '남천동 (smartboy1203):마타님?'],
#  ['20:36', '다데 (dadeshogun):그리핀 실질적 코치가 도파임'],
#  ['4:00:14', '밥보다빵 (wkdrh92):진짜 트할'],
#  ['4:08:32', '게으른혹등고래 (jinsihu):연기력늘었어진짴ㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['1:00:04', '보호주의구멍 (trtjbull6007):?'],
#  ['3:56:33', '민딘이 (dlrcoel):딜이 안될건데'],
#  ['1:49:04', '고양이가좋다 (glfhtkakd):개쌔네'],
#  ['3:44:37', 'roar8888:고릴라 잘땡기네'],
#  ['3:49:26', 'rksid:신 갓 혁'],
#  ['4:16:04', 'hztimothy:저거 한대 더 때렸으면 경기 아예 달라졌다'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:06:51'],
#  ['33:22', '저급어그로 (ekekr):오우야;'],
#  ['2:00:19', 'hygjh5:1퍼센트의 기적'],
#  ['4:03:33', 'dhgml0212:소라카는 왜 했냐진짜'],
#  ['4:33:43', '밋너 (kjihong9):나라 잃은 김구다'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 4:19:58'],
#  ['3:54:42', 'Spvls0613:와 페이커 ;;'],
#  ['3:55:07', '0레옹0 (kar5000):어머니,,,'],
#  ['4:40:17', '엘토네이도 (fpsava):?'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:17:05'],
#  ['1:32:11', 'qpemfh11:킹갓코어 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 국대정글러 ㅋㅋㅋㅋㅋㅋ'],
#  [' 게시 시간 30:50'],
#  ['37:01', 'ajden3:강타의신'],
#  ['3:40:33', 'Lalamut:이걸 맞추네, 평소 블랭크가 아니네'],
#  ['4:41:59', '딱코딱뎀딱카드 (potsurehi):페 석 머'],
#  ['27:39', '욱종이 (wookjong2):정글노잼이네'],
#  ['3:57:05', '하늘의또다른태양조강현 (parkga1342):간장게장 ㅋㅋㅋㅋ'],
#  ['2:08:50', '오나미오나홀 (yooyoungbin):문도 개무시가 답인가'],
#  ['4:36:23', 'kungs_kungs_kungs:적'],
#  ['1:01:58', '나는정환 (hahadin):진짜 아무말이나 막하네'],
#  ['2:55:09', '06_02_04:멈춤'],
#  ['1:15:23', 'buffadpls231:그리핀은 트릭이다'],
#  ['3:52:53', '버질반씨반다익 (jh5902):페이커 보이지 않는 1데스 있나'],
#  ['1:09:45', '동티모르꽃거지 (dzt2):유사말파이트'],
#  ['3:52:30', '갈라파고엔시스 (wgp2000):역시 히오스를 해야....'],
#  [' 게시 시간 18:04'],
#  ['2:05:02', 'kimbbongs:케넨 엠비피'],
#  ['1:02:17', 'lis0920:장어 ㄷㄷㄷㄷ'],
#  ['1:59:24', '나오토모리 (dudndltkdgus):ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['2:08:03', '렐다 (relda1):쥬시하라...'],
#  ['3:09:40', 'gjays96:용준할까 단군할까 ㅋㅋㅋ'],
#  ['1:37:37', 'nhg9696:갓 그리핀'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:21:06'],
#  ['4:40:22', 'h_e_y_guy:뱅ㅋㅋ'],
#  ['2:29:35', '캐종 (gold1022):ㄷㄷㄷㄷㄷ'],
#  ['3:30:26', '신이둥이 (siny_c):혼란하다 혼란해'],
#  ['39:37', 'jjla95:멀티테스킹 미쳤네'],
#  ['53:13', '힐러조 (wngh1423):함정 과학 ㄷㄷ'],
#  ['2:04:40', '주니황 (lkklklk):담당일진ㅋㅋㅋㅋㅋ'],
#  ['4:23:43', '한입만 (gur777):에포트 탐켄치네 졌다'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:03:49'],
#  ['4:33:40', '천칭별 (pjh71042002):ㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['4:36:50', '쪼카리 (hjjang1000):또간다ㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['2:59:11', 'moncher00:우천 때문에 시간 멈췄다네여'],
#  [' 게시 시간 16:29'],
#  ['4:34:50', '한잔할래 (gnsdudak):전자개돌??'],
#  ['1:33:45', 'userdew:ㅁㅍ'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 4:40:16'],
#  ['1:33:49', 'h_e_y_guy:ㅁㅍ'],
#  ['3:51:37', '맘스터치햄버거 (podong0990):와'],
#  ['4:33:43', '피조아 (whaql666):동 수 칸'],
#  ['1:41:22', 'dovoodoo1:바이퍼 케넨 끌어오고 케넨 궁터짐 ㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['20:58', '끌끌 (chydna):쵸비말고 다른 미드라이너는 누구임?'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 4:14:43'],
#  ['3:41:17', '루트루트루트 (qudrms2718):그리핀 떡발림'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:34:42'],
#  ['3:23:20', '브리슬 (qwdf29):갈라쇼'],
#  ['3:59:21', 'Coed3456:빛 혜 지'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 4:10:35'],
#  ['1:44:16', '토니웩 (tonywack1703):응 215'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:46:04'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:21:13'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:05:16'],
#  ['4:33:00', 'seonggon9494:동 수 칸'],
#  ['1:30:25', '검은건반 (junheon):오우예'],
#  ['1:32:43', '어디로든지 (rrg985):?'],
#  ['3:17:40', '서울은1시30분 (my562):커즈 ㄷㄷ'],
#  ['2:03:31', 'rokpd2007:케넨스맵못씀'],
#  ['1:45:06', '아나마타 (kcv4022):이건 대퍼다'],
#  ['1:09:40', '엑스펙스 (bydream11):쥬시하라'],
#  ['57:09', 'cubix111:그리핀 1.5 존끄들 했네'],
#  ['1:05:25', '리플리조커 (narajjang75):뭔가 마지막 롤챔스 같구먼..'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:45:36'],
#  ['4:08:30', '잭스밖에난몰라 (rlaxogjs92):.............'],
#  ['4:38:14', 'patmanbullet:oo'],
#  ['1:01:36', '딩동빌런 (ojh147):1세트 누가 이김?'],
#  ['3:49:05', 'MeMyselfAndIGG:상혁이 너무한데'],
#  ['2:28:27', '불낙전골허재 (sorh78):샤잭스보고와라'],
#  ['50:45', '급진적페미니스트김경현 (very_hot_fire_fist_gombo_):대ㅡㅡㅡㅡ퍼'],
#  ['2:04:28', '최강기아타이거즈 (qwe7363):아트럭스.너무 쌔다 ㄹㅇ'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 40:34'],
#  ['41:37', 'wasd002:KT가 담당 일진 되는거냐 ㄷㄷ'],
#  ['3:46:02', '흔한미일한국인 (grantmoon96):킹 릴 라'],
#  ['2:18:33', '배린배린배린이 (kong8986):ㅋㅋㅋ 진짜 개판인데?'],
#  ['4:39:34', '몽쉴통통 (hahaha345):ㅋㅋ'],
#  ['3:30:09', '노폐인노게임 (letmiraclesky):???????????????????'],
#  ['23:06', 'hmhee07:코돈빈!!!!!'],
#  ['47:16', 'guswns4087:아트록스 너프 시원하게 잘먹었다 ㄹㅇ'],
#  ['46:03', '리플리조커 (narajjang75):꼬오오오오오ㅜ???'],
#  [' 게시 시간 17:14'],
#  ['1:45:25', '구까이 (hankkang24):대퍼는 과학 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['4:40:31', '클템개잘함 (jic2438):에포트 뭐해'],
#  ['4:09:54', 'zjsxmfhf0:띵작'],
#  ['48:14', 'sang99246:원딜출현'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:01:42'],
#  ['3:49:02', '블랙베리 (rawkasa):이걸 트할이?'],
#  ['4:05:22', '루크로이 (jgj1807):ㅋㅋㅋㅋ딜량 ㅋㅋㅋㅋㅋ'],
#  ['4:32:56', '드루야캐요 (heyapples21):갓구'],
#  ['4:02:41', '매드야인 (sky3415):저 스킨이 피하기 넘 힘듬'],
#  ['1:41:50', '다시다마시다 (dismalian):가차없죠'],
#  ['1:11:58', '웁곰 (ooooooooooooooooooooopgm):와 쓸어담는다'],
#  ['55:08', '술꾼 (hcw698):대퍼'],
#  ['1:57:27', '누가물어봄 (factattacking):아니저거뭐냐고 ㅋㅋ'],
#  ['3:23:58', '조라땅다이스키 (younghwan33):팬덤이 커서 꼴팬도 많지'],
#  ['4:00:23', 'tenber1000:ㅁㅁ'],
#  ['50:12', '동티모르꽃거지 (dzt2):신입생 담당일찐 ㄷ'],
#  ['1:16:18', '멋진소나무 (skan3697):브라움밴해'],
#  ['4:09:53', '에키홀릭 (leejh0901):오지엔 약빨았나 ㅋㅋㅋㅋ'],
#  ['1:57:20', '공성과피자 (tdazzlili):소드마스터ㅓㅓㅓㅓㅓㅓㅓㅓㅓㅓㅓㅓㅓㅓ'],
#  ['39:15', '나는정환 (hahadin):용컨트롤 구리네'],
#  ['2:01:52', '가나다라마바사아자차카마 (txt1112):짱트록스님 그립습니다 ㅠㅠ'],
#  ['33:39', 'Maaagic11:뿔꽃의..'],
#  ['3:49:31', 'koiewq123:페이커합류 너무늦었네'],
#  ['49:50', '하와수 (chb8914):케이지'],
#  [' 게시 시간 13:19'],
#  ['3:43:24', '날아라곰탱이 (fbwjdgns05):잼구할뻔'],
#  ['3:30:07', '에이씨55 (sungwoo5957):뱅한태 모르거나 시키더니 이번엔 소라카냐'],
#  ['2:16:53', 'cleasky7:국 대 정 글'],
#  ['1:53:37', '챱챱넘좋아 (rabid527):넌해고 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:59:15'],
#  ['3:56:37', '츄랄 (shapeofm):ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['1:50:29', 'audcks94:대ㅡ퍼'],
#  ['4:37:43', '똘강 (fpel01):근데 슼은 초반 좋으면 개불안함'],
#  ['4:00:15', '크라이2 (ghyenkim):트할 개똥싸네'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 4:03:46'],
#  ['1:57:33', '멍청아메룡 (ambbadda):ㅋㅋㅋㅋ 동수칸 팀운 안좋은거봐 ㅋㅋㅋ'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 4:11:26'],
#  ['3:34:55', '대장나아무 (khm9907):저게 끌리네'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:05:57'],
#  ['1:45:15', '끈끈 (rmsqja94):대퍼타임'],
#  ['4:04:41', 'oarseller1:운블페벵울 나와라'],
#  ['3:51:52', '똘망똘망 (kimgang1102):핵 꿀잼'],
#  ['3:57:17', '우유에빠진냥이 (dkue3):뭔가 이상한 이득 ㅋㅋㅋㅋㅋㅋㅋ'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:38:59'],
#  ['3:28:00', '류설혜 (jjh42566):페이커 특) 블라디하면 짐'],
#  [' 게시 시간 17:45'],
#  ['3:30:33', 'jang2031:아 트롤픽 ㅋㅋㅋㅋㅋㅋㅋ'],
#  ['4:08:58', 'whitemoon789:구와아아아악... 아이엠그루트;;'],
#  ['4:40:30', '류드밀라 (601cool713):크'],
#  [' 게시 시간 17:05'],
#  ['4:13:08', '우유에빠진냥이 (dkue3):칸 목 ㄷㄷ'],
#  ['1:52:01', 'Geryos12:비전 투시'],
#  ['2:05:04', '똥덱장인따혀니 (samuelas215):K2:G0ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['1:58:57', '업사 (yp071605):슈-퍼팀이었다'],
#  ['3:37:56', '똘망똘망 (kimgang1102):저거왜삼? 평타거리안담?????'],
#  ['1:10:12', 'hoonisa:갈아버려'],
#  ['3:50:59', '뭐되더놈 (illegalp1):ㅋㅋㅋㅋㅋㅋ'],
#  ['2:04:14', 'kokcal:크'],
#  ['1:45:26', '집관리인 (woong1519):대ㅡㅡㅡㅡㅡㅡ퍼'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:38:22'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 59:40'],
#  ['4:03:37', '느허으악 (ghdwls999):싫어 ㅋㅋㅋㅋ'],
#  ['2:03:46', '포코라 (pokora3823):대-퍼 올뻔 ㅋㅋ'],
#  ['4:38:30', '환상 (toytanicc):칸이 얼마나 망했냐면 정글보다 렙 낮음 ㅋㅋㅋ'],
#  ['3:49:21', '으아아아앆 (dwanjjang):않이 라칸 정글 뭐임?ㅋㅋㅋㅋ'],
#  ['3:47:25', '왁희 (khm99629):슼팬들은 항상 탓하기 바쁘네 서폿차이가 아니라 그냥 팀차이다'],
#  ['3:46:12', '건우디 (mtwelvebk):이게왜 잼구냐ㅋㅋㅋㅋ'],
#  ['1:06:00', 'kolk23:갓경누나....그립읍니다....'],
#  ['58:34', '스졸렬 (mlli1412):모데 w 비빈거도 크다'],
#  ['1:09:16', '힐러조 (wngh1423):삼각혀 ㅗㅜㅑ'],
#  ['2:07:54', '베개랑나랑 (ranafl):스맵 뒷텔이 하이라이트지'],
#  ['4:46:46', 'did_gombo_enlist_yet:문도 사기는 맞아 롤알못아'],
#  ['4:42:51', '달패앵이 (marine732k):트할 킬먹고 하는거 없음'],
#  ['1:50:44', '나무깍는노인 (dkzlakfn):진짜 용준이과학이야'],
#  ['4:34:28', 'kuramati:ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['30:13', '텐서스 (gyeongbin):어깨 싸움봐 ㅋㅋㅋㅋㅋㅋ'],
#  ['2:16:47', '오다주웠다 (kasibo7):zzzzzzzzzz'],
#  ['2:26:19', 'wkdudrhkd:그악타 ㅋㅋㅋㅋㅋ'],
#  ['1:45:12', 'kaloce1:스맵이 제대로 던졌다'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:30:24'],
#  ['2:10:11', 'Alche96:ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['3:45:17', '믛흠믛흠믛 (eogks9090):봇이 밀리는게 좀 크네'],
#  ['4:08:01', 'rkaak33:2경기땐 선수 바꾸자'],
#  ['3:33:44', '겉은바삭속은촉촉한조팡현 (garrosh_hellsteelo):투미드 ㄷㄷㄷㄷ'],
#  ['53:29', 'zkze357:그리핀 밴픽 뭐 자따구로함?;;'],
#  ['4:32:53', '흐에호야홋 (tjdwnszxcv):오늘 갓구 잘하네'],
#  ['3:32:09', '메론파 (wkfmwnd):혜지 모름???'],
#  ['4:31:22', '혀낙이 (jar5382):6승1패임'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:30:04'],
#  ['3:59:07', '쓰팀 (khj921227):플ㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['4:20:12', 'Npn1934:트할 : 던짐 ㅅㄱ'],
#  ['1:45:06', 'ㅁㄴ (rno159):대퍼'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:54:06'],
#  ['4:14:25', '나는꿈에서나비였소 (someaugust17):빛돌.. 제발 안나왔으면....'],
#  ['2:10:21', 'dkrnwl11:춘봉바크'],
#  ['1:31:39', '아삼작클라크 (bibo502):ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['1:52:40', '트위치마니보는사람 (twitchjoaing):평범한 대퍼자나?'],
#  ['4:04:51', 'aowldps:ㄱㅁ'],
#  ['1:45:21', '피마원 (ljhzzang1530):용-준'],
#  ['4:07:58', 'yuredong:1+1ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 4:24:32'],
#  ['4:39:33', '향시 (ashwhite):ㅋㅋㅋㅋㅋㅋ'],
#  [' 게시 시간 8:24'],
#  ['1:45:50', '백수왕한백수 (vpcea25fk):타잔 개잘하네진짜'],
#  ['54:11', 'everlong09:ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['1:31:25', '채팅창무게감오지죠 (uh6400):와'],
#  ['1:32:38', 'Sococt54312:?'],
#  ['4:08:41', '남산코렁탕 (ydmg0):클하다 추템아'],
#  ['1:50:30', '양을쫓는아이 (wonterkid):ㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['3:54:42', '희섭 (khsdfg952):우리혁이맞습니다'],
#  ['1:37:39', 'irnalf:대퍼 ㅇ오반데'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:32:51'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 49:07'],
#  ['4:43:04', '크롱크룽크롱 (tavasz114):뱅 너무못했어 스웨인'],
#  ['3:55:12', '휘파람파람파람파람 (britzrush):와 근데 오늘 꿀잼이네 ㅋㅋㅋㅋㅋㅋㅋ'],
#  ['18:53', '평범한하늘 (blueskyer00):그리핀 세트포함해서 2패밖에 안했네..'],
#  ['33:39', '싼타 (dnqjqud):폭격기'],
#  ['2:12:53', 'iuiurm:크 유신병 답변이 모범적이야'],
#  ['3:11:22', 'ykjk1401:히오스'],
#  ['4:02:23', '몬짐 (monstergym):아주 블리츠오니깐 아무고토모타쥬'],
#  ['1:45:06', '쿨파 (bsh2313):춘봉씨 대퍼'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 47:58'],
#  ['3:44:34', '홀생 (tlsdltls):잼구똥꾸'],
#  ['1:26:54', 'mike6636:슼그리핀한테 이미한번 짐'],
#  ['1:07:32', '좌동준 (leftdongjun):갓살표 ㄷㄷ'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:22:56'],
#  ['4:04:54', '피오옝 (wogur2545):미드차이인듯 ㅋㅋ'],
#  ['3:58:22', '쉴라이트 (powjddlr):??'],
#  ['4:18:41', 'gkdmdrk:ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['2:07:57', 'zoqxlsgh:딜보소 킹트록스'],
#  ['3:28:20', 'ms20485039:kt'],
#  ['1:41:15', '싼타 (dnqjqud):폭격기가 불까지 끄네'],
#  [' 게시 시간 6:13'],
#  ['1:08:07', 'splloover:갓콩'],
#  ['3:46:08', '쌈바쌈바 (gkwk70):잼구는 못말ㄹ'],
#  ['1:12:18', '2월의귀인 (yorsion):쥬씨하라아'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 4:28:01'],
#  ['4:03:45', '멋진소나무 (skan3697):진짜 고ㅜ릴라 미쳣다'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:45:45'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:08:55'],
#  ['4:18:26', 'cocopalm22:아프리카 가야지 싱크안맞아서 못보겠따'],
#  ['2:05:46', 'wjdtn1013:스맵킹넨이지렷음'],
#  ['4:26:42', '탑정글만갈게요 (cdy2732):블라디를해 제발 트할형'],
#  ['29:57', '침대인간 (applier):노딜조합 ㅋㅋ'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 52:14'],
#  ['4:04:21', 'sa2daman:금수의 왕'],
#  ['1:43:05', 'Legendrend:??????'],
#  ['3:09:23', '무지개색미라클 (korsolar):ㅇ'],
#  ['3:36:41', 'givemetip:ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  [' 게시 시간 12:24'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:28:29'],
#  ['4:21:59', '로맨스토커 (kmoh7737):스카너 갈리오 조합 나올듯'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:07:10'],
#  ['2:41:58', '15살푸틴피푸틴 (du9172):싹뚝이 아다 짤림 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['4:44:46', '카레다음깍두기 (curry5939):짜오 유통기한와서 망함'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 4:22:43'],
#  ['3:22:33', '포스트지 (park1713):페이커..'],
#  ['2:02:32', 'kamatasong:그리핀 거품 다 빠지네'],
#  ['4:25:52', '최종학력피자스쿨 (olll):그브각'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:03:33'],
#  ['1:36:35', '박용 (pakyong):물럿거라!'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:30:09'],
#  ['3:30:14', 'gourmetnut:리폿 ㅅㄱ'],
#  ['3:54:27', '마베이스 (madrumm):와 빠커 ㅋㅋㅋㅋ'],
#  ['2:07:10', 'zecrastar:ㄹㅇ'],
#  [' 게시 시간 3:03'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:47:46'],
#  ['1:45:07', '허미트29 (dbsdydgml20):그리핀의 한타'],
#  ['1:45:44', '난방고냥이 (neutonic8915):스매부가 이걸 ㅋㅋㅋ'],
#  ['1:51:53', '로스카흑우 (march1157):전투를 하지 않을 시'],
#  ['1:50:15', 'Uang0622:야 근데 문도가 안죽어 ㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['4:03:25', '하이어1 (higherplace1):aa'],
#  ['2:04:53', '낭낭쭙쭙 (xellew147):신입생 이기고 너모 좋아한다 ㅋㅋㅋㅋㅋㅋㅋ'],
#  [' 게시 시간 8:05'],
#  ['58:15', '자칼54 (na6game):딜 안박히는거보소 야스오'],
#  ['1:16:10', 'mudohaha:춘봉박 1세트 날라다님'],
#  ['1:52:03', '계략 (gyeryak):Vision 투시'],
#  ['1:29:11', 'dwadwwq:ap케넨이네'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:41:27'],
#  ['4:22:48', '그이유르흐을 (aldksgodld):왤케 흐릿함 해상도꺠지는거봐'],
#  ['46:54', '토토로기여워 (totoro0216):와 도발각도 스킬각도 예술..'],
#  ['4:29:36', '박무지 (powernanana):뱅기 아련...'],
#  ['4:40:16', '흑안개 (sans8462):정글냠냠'],
#  ['4:40:28', '리야제 (tom880726):둥글게 둥글게'],
#  ['41:47', 'explorer8595:KT가 뜬금없이 이런애들 잡더라'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:34:07'],
#  ['3:39:44', '쿠우닥터 (cruelbait):ㅋㅋㅋ이걸 먹네'],
#  ['1:10:52', '로봇 (aiuansd):안녕'],
#  ['42:57', '씨리얼다내꺼 (d2245no1):와 진짜 해설차이오진다'],
#  ['42:43', '요들법사 (kbh1420):전승 담당 일찐 ㅋㅋ 쉔 짜른게 진짜 좋은 밴픽이였다'],
#  ['2:01:06', '따워 (rktower010):발싸!!!!!'],
#  ['32:08', 'lensio16:비비큐 롤드컵 우승스킨;'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 58:14'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:16:08'],
#  ['2:09:52', 'qqqq784512:??????????'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 47:11'],
#  ['3:30:44', '팬티색이머냐 (kiker0):머여'],
#  ['3:49:53', 'eogkrdnjs:소라카 궁이'],
#  ['4:33:26', '초련행 (noctiluca001):한입만 ㅜㅜ'],
#  ['3:57:02', 'hhchong:ㅁㅍ'],
#  ['4:33:54', 'zephyk7:나라 잃었다 동수칸'],
#  ['4:36:17', '차냥한다 (t53171213):줄건줘'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 4:23:31'],
#  ['4:01:41', '우리번 (smrmqjs):저걸 그럼 안오냐 븅들 결과론지리네'],
#  ['1:37:28', '풍멍댕이 (wish824):대 퍼 타 임'],
#  ['1:53:34', '끄로마뇽 (simin0316):넌 해고얔ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['1:58:24', '평범한정원사 (pak113665):ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['1:40:57', 'mummoomy:춘넨 ㄷㄷㄷ'],
#  ['4:06:07', 'abcd0654:페이커 넋나간거보소'],
#  ['14:40', '돼지강신우 (ksw3214):스포티비가 누나들볼수잏어서 좋은데 ㅠㅠ'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 49:14'],
#  ['4:33:01', '빅2 (asda725):야구나이트'],
#  ['3:54:24', '해아니 (dlfghldyd4684):?'],
#  ['1:51:10', '차레이 (asheka):혐도 풀피 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['3:31:02', 'tkddyddl:ㄹㅇ 혼돈'],
#  ['3:27:59', '씹덕혐오자 (dltlgud8426):페이커 카시 가즈아ㅏㅏㅏㅏㅏㅏㅏ'],
#  ['1:41:04', '얼어붙은왕국의룩공얍 (carta987):와 신맵ㅋㅋㅋㅋㅋ'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:35:43'],
#  ['56:17', '웁곰 (ooooooooooooooooooooopgm):매치 패배하나?'],
#  ['40:47', 'Zhfspt:리멕 아트록스 꾸지긴 꾸졌더라'],
#  ['57:59', 'flamewarhammer:Juicy하라~'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:15:48'],
#  ['3:12:47', 'deuxmj123:SKT이기즈아'],
#  ['3:35:30', '몬짐 (monstergym):소리싱크왜이래'],
#  ['53:26', '보노씨 (cdragon777):야스오이즈 사이언스'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:30:11'],
#  ['1:37:31', '킬리안음바페 (zlffldksdmaqkvp):춘봉박 ㄷㄷ'],
#  ['1:56:43', '나성호임 (tjdgh9629):문도 와애댈텐데'],
#  ['1:54:12', '응기잇삼봉이 (tlfwkdtjr):쫄'],
#  ['3:19:01', '정힙오 (ghdiwltkd):이제 울프는 ...'],
#  ['1:29:40', '열2 (duf21122):비원딜 원딜이 뭐냐...'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:30:12'],
#  ['3:54:52', 'shin1120:소라카 ㄷㄷ'],
#  ['1:09:22', '아두이노 (randruner):55도발 ㄷㄷ'],
#  ['1:08:35', '띠띵띠띵띠 (insengiran):빛돌쟝 오늘도 셔츠 못다렸네'],
#  ['1:42:22', 'sindc37:그리핀 진짜 거품이었나?'],
#  ['4:03:56', '애증 (lachesis105):커즈 라칸 왜케잘하냐 ㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['1:31:29', '윾두의권 (fist_of_nipple):야 대 한 코 글 러'],
#  ['3:37:12', '앵준이 (hyunjunnk):ㅡ할 진짜 ㅡㅡ'],
#  ['44:38', '로파파_유칼 (skasa37):KT=Korean Team ㄷㄷ'],
#  ['3:37:14', 'Hasiri88:아니 트할 머해'],
#  ['2:10:34', '아리까ㄹㅣ (apfqyfpd):춘봉박 내이놈!!!'],
#  ['45:40', '뽀삐냥 (mioioio):야 나 소름돋았어'],
#  ['2:07:03', 'oince3547:킹 맵'],
#  ['1:08:12', 'disco4194:미 ㅡ리'],
#  ['1:00:12', '너무하자너 (kht1906):ㅗㅜㅑ'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:51:51'],
#  ['4:40:03', '꾸구꿀 (zerg0918):킹디디'],
#  ['2:04:33', 'hamen2:대 크 트'],
#  ['20:15', '트레이터 (skysyj117):필 리 핀'],
#  ['1:10:54', '항상조심해 (xzc325):관종듀옼ㅋㅋㅋㅋㅋㅋ'],
#  ['1:25:58', 'amgmtamgmtamgmt:카밀 승률낮춘건 잼구다'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:38:32'],
#  ['3:55:17', 'holy1026:트할이 진짜 제일 못해'],
#  ['3:47:31', '티엠티 (eldkqnfwh12):ㅋㅋㅋㅋ'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:34:59'],
#  ['4:00:55', '라밤바_ (cyd9486):ㅅㄱ'],
#  ['3:25:22', 'jsw0641:세주 각'],
#  ['3:46:08', '봉구몽구 (whatsupcu89):꼬갓'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:05:26'],
#  ['53:16', '망고샴푸 (garnetring):과학'],
#  ['2:00:13', 'qwer8888:전반은 못봣찌만 ㅋㅋㅋㅋ'],
#  ['3:15:25', '패러디 (kdk8361):묘비다 묘비!'],
#  ['4:20:15', 'sang99246:슼또졌구나'],
#  ['3:20:18', '빠삭한새우칩 (zero9566):방어율 보소 ㄷㄷㄷ'],
#  ['4:15:33',
#   '싹둑 (ssakdook):▣ 채팅방 상황에 따라 슬로우 모드 적용이 이루어질 수 있습니다. ▣ 비속어 및 도배 등에 대해서는 필터링이 진행 중이니 매너 채팅 부탁드립니다. (_ _) ▣'],
#  ['4:22:38', 'OneHand31677:대놓고 어그로 끄네 에라이 정신병..'],
#  [' 게시 시간 13:31'],
#  ['4:42:13', '샨드위지 (sandwizhi):?'],
#  ['4:21:24', 'shaksn3838:곰ㅡ보'],
#  ['3:34:51', '여원 (illusion0416):와'],
#  ['1:41:06', '초보누에 (dksktkwl):와 빛맵 짱잘해 ㅋㅋ'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 50:11'],
#  ['50:55', '누누그만해 (wls3928):kt타임 ㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['58:54', '침묵규칙 (2020tofhdnj):쥬 - 시 하라'],
#  ['3:49:15', 'ansdnjs12:힐왜안찍냐'],
#  ['1:51:46', '잘됐으면좋겠다 (gkdltlzj):전투 아닐때'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:32:15'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:08:57'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 59:51'],
#  ['4:00:56', '여원 (illusion0416):개꿀잼'],
#  ['3:27:35', '나무깍는노인 (dkzlakfn):혜지야 강타말고힐들어'],
#  ['22:57', '깜초 (kph2860):코 돈 빈 ㅋㅋㅋㅋㅋㅋㅋ'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:35:23'],
#  ['2:41:01', '초코맛딱풀 (gluestick127):짐'],
#  ['1:45:26', 'smck05:대 퍼 타 임'],
#  ['3:30:12', 'YameKri:아니 이게 뭔짓거리야'],
#  ['4:26:18', 'gozillason:"적"'],
#  ['1:46:07', '불여우아리 (lovelin136):전요운 개잘하네'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 1:09:55'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:00:31'],
#  ['4:03:06', '이러면이제프로토스가 (khirai1):슼 미드 킬먹고 하는게 뭐냐'],
#  ['3:43:27', '크산티노 (kimtino):빛구'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:35:56'],
#  ['3:34:51', '다닭 (ckdduq428):ㅁㅁ'],
#  ['1:45:22', '빻__빻 (cantataowo):대 ㅡ 퍼'],
#  ['2:01:33', 'gerek010:녹턴궁 벌써 반이네 ㅋㅋ'],
#  ['3:23:29', 'cherryblossom:팬들싸움이다'],
#  ['36:12', '세이프티 (saint_lucia):또바나 노잼톤시절?'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 2:31:17'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 24:01'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:50:56'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 3:17:07'],
#  ['3:49:57', '바꿔줘제발 (wlsdyd0505):무밍'],
#  ['51:47', 'k1dl3ad3r:오우 갓리핀 지고있네'],
#  ['3:51:45', '욕은하지말죠 (nsjujje):소라카원딜 뫄냐 ㅋㅋㅋㅋㅋㅋㅋ'],
#  [' 게시 시간 18:54'],
#  ['4:04:49', 'preludeJJ:투할'],
#  ['4:21:52', 'vjfjdfkqpf:ㅗㅜㅑ'],
#  ['시청자 설정생방송 중 게시된 메시지만 보기타임스탬프 숨기기 게시 시간 4:36:57'],
#  ['3:35:01', 'python00:이걸 혜지가?'],
#  ['3:49:19', '달콤한정수씨 (ehw8042):커즈자랫네'],
#  ['3:34:40', 'rkaak33:이럴거면 자기 잘하는 챔 골라서 라인스왑하면 되는거 아니냐'],
#  ['45:30', 'nhlh7l:와'],
#  ...]

# %%
import pandas as pd

# %%
dataset=pd.DataFrame(lis2,columns=['time','ID'])

# %%
dataset=dataset[~dataset.time.isna()]

# %%
dataset=dataset[~dataset.time.str.contains('게시')]
dataset=dataset[~dataset.ID.str.contains('싹둑')]

# %%
dataset=dataset.reset_index().iloc[:,1:]

# %%
b=list(dataset.ID.str.split(':',n=1))

# %%
data_preprocessed=pd.concat([dataset.iloc[:,0],pd.DataFrame(b,columns=['ID','comment'])],axis=1)

# %%
data_preprocessed.isnull().sum()
# Out:
# time       0
# ID         0
# comment    0
# dtype: int64

# %%
data_preprocessed
# Out:
#           time                                       ID  \
# 0      4:06:27                          초보누에 (dksktkwl)
# 1      4:03:52                       남천동 (smartboy1203)
# 2      3:56:55                      운타라최고다 (sogogi0816)
# 3      3:41:53                          귀여운아롱이 (ero100)
# 4      3:24:25                                 jang2031
# 5        52:48                                IolFranco
# 6      1:50:19                                 arnapola
# 7      1:14:41                         차냥한다 (t53171213)
# 8      4:04:25                              naaaaamoooo
# 9      1:58:36                      마트료제시카 (matroska94)
# 10     2:04:42                                 ggdog444
# 11     3:52:20                            exteriorglass
# 12     4:36:30                                  wbo0622
# 13     3:55:12                        밤에피는장미란 (kyant13)
# 14       50:48                       선지쉐이크 (blessthief)
# 15     3:18:20                           제프티 (leinpols)
# 16     4:34:18                                 binstyle
# 17     1:01:53                    누가물어봄 (factattacking)
# 18       29:51  급진적페미니스트김경현 (very_hot_fire_fist_gombo_)
# 19     1:31:56                                 zcxv1234
# 20     1:56:43                        만긍이 (rockman0810)
# 21     2:10:52                            엔소르 (kieltre)
# 22     4:31:02                                  omh1555
# 23     2:14:56                          라무네 (likeingan)
# 24       52:35                           침대인간 (applier)
# 25     1:09:19                        eagleeye_mincheol
# 26     2:23:42                            애비게일 (ymh708)
# 27     3:55:51                                  rpcn545
# 28     3:46:54                       천연밀가루 (wnsgur3638)
# 29     2:03:02                         톡구99 (toesu2435)
# ...        ...                                      ...
# 30863  3:39:12                        나무깍는노인 (dkzlakfn)
# 30864    30:53                                 qqqppqp1
# 30865  4:32:58                       갓겜디비전 (auntgu1945)
# 30866  1:46:24                        타마냥 (dltjdqja726)
# 30867  1:45:18                             싼타 (dnqjqud)
# 30868  4:41:14                        마늘맛사탕 (mymaks682)
# 30869  1:51:31                                  rhd6919
# 30870    13:36                         또옹키 (wearead100)
# 30871  4:33:05                       ㅅㅔ나 (lylameowmeow)
# 30872  3:38:17                        갈릭버터맛우결충 (kphsws)
# 30873  1:58:29                     오나미오나홀 (yooyoungbin)
# 30874  1:37:52                        모닝두유 (csbluebear)
# 30875    25:40                    강남고양이 (blueseven2244)
# 30876  4:33:39                       휴지아까워 (wjdjbk0611)
# 30877  4:42:37                                 cleasky7
# 30878  3:51:39                               ehdals1104
# 30879  4:34:21                         구아아아악 (jgpower2)
# 30880    53:08                       근엄한머법관 (smartsi08)
# 30881  4:03:31                                theshin10
# 30882  1:50:18                          슬각 (lamaaaaant)
# 30883  4:33:54                                  kahahah
# 30884  3:49:34                                   escs23
# 30885  2:05:31                       무독성딱풀 (heaven1206)
# 30886  4:33:40                              SchwarzTee3
# 30887    41:35                            우리샤론 (as4914)
# 30888  2:06:05                                 Chamring
# 30889  1:13:19                        청안하다 (kinggeopum)
# 30890  2:10:09                        좌동준 (leftdongjun)
# 30891  3:15:10                                   pphjqq
# 30892  3:44:49                       피묻은수수깡 (nallancat)
#
#                                     comment
# 0         와 진짜 꼬갓 넘넘 미쳤음 퍄퍄퍄퍄 ㅠㅠㅠㅠㅠㅠㅠㅠ 개머싯어
# 1                                      ㄱㅈㅁㅁ
# 2                                        갓구
# 3                                     혜지 굿~
# 4                                   크 엳시 동준
# 5                             야스오 바로리쉬중 ㅋㅋㅋ
# 6                                 대ㅡㅡㅡㅡㅡㅡㅡ퍼
# 7                                      ????
# 8                            소라카도 하는거없어 왜픽함
# 9                                     장로 미췬
# 10                                   대퍼의 기적
# 11                               트할템머야 저거왜감
# 12                                  잼구 : 던짐
# 13                                뱅 점멸힐 ㅋㅋㅋ
# 14                                     대퍼타임
# 15                                얘들 신났네 ㅋㅋ
# 16                                        ?
# 17                                        ?
# 18                                미쉐린 + 용준좌
# 19                                    대 동 빈
# 20                               2명이 덮쳐 ㅗㅜㅑ
# 21                                     이이이잉
# 22                                  싱크 개판이네
# 23                                프로도 힘듬 ㅋㅋ
# 24                               ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 25                             뭐냐아! ㅋㅋ 스포티비
# 26                                    케스팤ㅋㅋ
# 27                            진짜 재밌다 ㅋㅋㅋㅋㅋㅋ
# 28                                       ??
# 29                                     그 자리
# ...                                     ...
# 30863                            탑킬같은소리하젶ㅋㅋ
# 30864                            야스오는 마른근육임
# 30865                           아 노어시 던짐 ㅡㅡ
# 30866                                    잼이
# 30867                             케넨 위치가 ㅉㅉ
# 30868                         페이커 앞점멸이 오바였다
# 30869                                   3바람
# 30870                                   왜냐!
# 30871                               와 오늘 갓구
# 30872            그냥 전패해라 하.... 팬질하기도 힘들다 진짜
# 30873                         피카츄 이니시 ㅆ상타치네
# 30874                    타잔 컨디션은 확실히 안좋아보인다
# 30875                               러쉬 어디감?
# 30876                                 32대 9
# 30877                     제압킬 꺼ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ억
# 30878                             ㅋㅋㅋ진짜 재밌네
# 30879                        ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 30880                               야 이 언 스
# 30881                              고릴라가 다하네
# 30882                         혐도 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 30883                                아이고...
# 30884  소라카 잡으러 안가고 다같이 스웨인 포커싱 하는게 더 나았을 텐데
# 30885                          바이퍼 감독을 무시하네
# 30886                                야 우냐??
# 30887                                   쥬-시
# 30888                                 갓데카이져
# 30889                          머호형갈수록 잘생겨지네
# 30890                  인싸 외모ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 30891                              이게 오프닝이지
# 30892                      근데 이거 조합이 킹존이 좋아
#
# [30893 rows x 3 columns]

# %%
data_preprocessed.to_csv('./data/video_'+code+'.csv',encoding='utf-8',index=False)

# %%
#dataset=pd.read_csv('./data/video_298776271.csv')

# %%
for i in range(0,len(dataset.time)):
    if len(dataset.time[i])==4:
        dataset.time[i]='0:0'+dataset.time[i]
    elif len(dataset.time[i])==5:
        dataset.time[i]='0:'+dataset.time[i]

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\jimmi\\Desktop\\빅데이터\\캡스톤_2학기\\까치\\까치'
