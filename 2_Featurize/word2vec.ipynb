# %%
import pandas as pd
import numpy as np
#import torch
#import torchvision
#import torch.nn as nn
#import torch.optim as optim
#from torch.autograd import Variable
from sklearn.model_selection import train_test_split
from konlpy.tag import Twitter
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import random
from pprint import pprint

# %%
import pickle

with open("./pickle/token_data.pickle", "rb") as f:
    token_data1 = pickle.load(f)
    
with open("./pickle/token_data_final4.pickle", "rb") as f:
    token_data2 = pickle.load(f)
    
with open("./pickle/token_data_group4.pickle", "rb") as f:
    token_data3 = pickle.load(f)
    
with open("./pickle/token_data_317807282.pickle", "rb") as f:
    token_data4 = pickle.load(f)
    
    
with open("./pickle/token_data_278501686.pickle", "rb") as f:
    token_data5 = pickle.load(f)
    
with open("./pickle/token_data_325411081.pickle", "rb") as f:
    token_data6 = pickle.load(f)

with open("./pickle/token_data_244954127.pickle", "rb") as f:
    token_data7 = pickle.load(f)

# %%
comment1=token_data1['comment']
comment2=token_data2['comment']
comment3=token_data3['comment']
comment4=token_data4['comment']
comment5=token_data5['comment']
comment6=token_data6['comment']
comment7=token_data7['comment']

# %%
len(comment1)+len(comment2)+len(comment3)+len(comment4)+len(comment5)+len(comment6)+len(comment7)
# Out:
# 311020

# %%
for k in comment2:
    comment1.append(k)
for k in comment3:
    comment1.append(k)
for k in comment4:
    comment1.append(k)
for k in comment5:
    comment1.append(k)

for k in comment6:
    comment1.append(k)

for k in comment7:
    comment1.append(k)

# %%
print(len(comment1))
print(len(comment2))
print(len(comment3))
print(len(comment4))
print(len(comment5))
print(len(comment6))
print(len(comment7))
# Out:
# 311020
# 68453
# 52111
# 33468
# 30893
# 53332
# 27238

# %%
#import pickle

#save_data = {
 #   "comment": comment,
#}

#with open("./pickle/통합버전_11_14.pickle", "wb") as f:
 #   pickle.dump(save_data, f)

# %%
comment=comment1.copy()

# %%
len(comment)
# Out:
# 311020

# %%
#comment = token_data["comment"]
#target = token_data["target"]
#reviews_idx = token_data["comment_ix"]
#word2idx = token_data["word2ix"]
#idx2word = token_data["ix2word"]
#max_seq_length = token_data["max_seq_length"]
#idx2target={1:'highlight',0:'no'}

# %%
from gensim.models import Word2Vec

# %%
model = Word2Vec(comment, size=100, window=5, min_count=3, sg=1, workers=4, iter=1000)
model.save("word2vec_50_total.model")

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import random
from pprint import pprint

random.seed(7)

#model = Word2Vec.load('word2vec.model')
#model = Word2Vec.load('word2vec.model')

# %%
from matplotlib import font_manager, rc

# %%
font_location = "./NanumBarunGothicLight.ttf"

# %%
font_name = font_manager.FontProperties(fname=font_location).get_name()
print(font_name)
# Out:
# NanumBarunGothic

# %%
rc('font', family="NanumBarunGothic")

# %%
num_samples = 200
word_list = random.sample(list(model.wv.vocab.keys()), num_samples)
embeddings = [model[word] for word in word_list]

pca = PCA(n_components=2).fit_transform(embeddings)

plt.figure(figsize=(30, 30))
plt.scatter(pca[:,0],pca[:,1], c="r")
for i, txt in enumerate(word_list):
    text = txt.split("/")
    if len(text[0]) > 1:
        plt.annotate(text[0], (pca[i,0], pca[i,1]), size=22)
#plt.xlim(-0.75,0.75)
plt.show()
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
